# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dark_mode = True
# plotting choices for dark-mode
if (dark_mode):
    from jupyterthemes import jtplot
    jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
    linecolor = 'w'
else:
    linecolor = 'k'
    
plt.rcParams["figure.figsize"] = (16,32)

figure, axis = plt.subplots(1, 1)
plot1 = plt.subplot2grid((2, 1), (0, 0), rowspan=1, colspan=1)
#plot2 = plt.subplot2grid((2, 1), (1, 0), rowspan=1, colspan=1)

df2 = pd.read_csv('o2_sensor_2_voltage.csv',header=None)
df1 = pd.read_csv('o2_sensor_1_current.csv',header=None)

plot1.set_xlim([61300,61335])
plot1.set_xlim([61300,61335])
plot1.plot(df1[0],df1[1])
plot1.plot(df2[0],df2[1]-0.9)

# %%
plt.rcParams["figure.figsize"] = (16,32)

figure, axis = plt.subplots(1, 1)
plot1 = plt.subplot2grid((2, 1), (0, 0), rowspan=1, colspan=1)
#plot2 = plt.subplot2grid((2, 1), (1, 0), rowspan=1, colspan=1)

df2 = pd.read_csv('o2_sensor_2_voltage.csv',header=None)
df1 = pd.read_csv('o2_sensor_1_current.csv',header=None)

plot1.set_xlim([61430,61475])
plot1.set_xlim([61430,61475])
plot1.plot(df1[0],df1[1])
plot1.plot(df2[0],df2[1]-0.9)
