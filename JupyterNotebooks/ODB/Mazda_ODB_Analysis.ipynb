# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dark_mode = True
# plotting choices for dark-mode
if (dark_mode):
    from jupyterthemes import jtplot
    jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
    linecolor = 'w'
else:
    linecolor = 'k'

df = pd.read_csv('Mazda_CX5_2016_08122022.csv',delimiter=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18498 entries, 0 to 18497
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SECONDS     18498 non-null  float64
#  1   PID         18498 non-null  object
#  2   VALUE       18498 non-null  float64
#  3   UNITS       15099 non-null  object
#  4   LATITUDE    18498 non-null  float64
#  5   LONGTITUDE  18498 non-null  float64
#  6   Unnamed: 6  0 non-null      float64
# dtypes: float64(5), object(2)
# memory usage: 1011.7+ KB

# %%
df.head(100)
# Out:
#          SECONDS                                           PID       VALUE  \
# 0   61163.575861                                Altitude (GPS)   90.040106
# 1   61164.066861                                Altitude (GPS)   91.049061
# 2   61164.066861                           Average speed (GPS)    0.000000
# 3   61164.066861                                   Speed (GPS)    0.000000
# 4   61164.151861                                Altitude (GPS)   91.049061
# ..           ...                                           ...         ...
# 95  61217.612861          Catalyst temperature Bank 1 Sensor 1  227.120000
# 96  61217.612861       Oxygen sensor 1 Wide Range Current (mA)    0.000000
# 97  61217.612861  Oxygen sensor 1 Wide Range Equivalence ratio   14.718882
# 98  61217.612861   Oxygen sensor 2 Bank 1 Short term fuel trim    0.000000
# 99  61217.612861                Oxygen sensor 2 Bank 1 Voltage    0.075000
#
#    UNITS   LATITUDE  LONGTITUDE  Unnamed: 6
# 0   feet  37.255327  -76.736260         NaN
# 1   feet  37.255327  -76.736260         NaN
# 2    mph  37.255327  -76.736260         NaN
# 3    mph  37.255327  -76.736260         NaN
# 4   feet  37.255099  -76.735947         NaN
# ..   ...        ...         ...         ...
# 95     ℉  37.255337  -76.736099         NaN
# 96    mA  37.255337  -76.736099         NaN
# 97   NaN  37.255337  -76.736099         NaN
# 98     %  37.255337  -76.736099         NaN
# 99     V  37.255337  -76.736099         NaN
#
# [100 rows x 7 columns]

# %%
df2 = df.loc[df['PID'] == 'Altitude (GPS)']

# %%
df2.head()
# Out:
#         SECONDS             PID       VALUE UNITS   LATITUDE  LONGTITUDE  \
# 0  61163.575861  Altitude (GPS)   90.040106  feet  37.255327  -76.736260
# 1  61164.066861  Altitude (GPS)   91.049061  feet  37.255327  -76.736260
# 4  61164.151861  Altitude (GPS)   91.049061  feet  37.255099  -76.735947
# 5  61164.651861  Altitude (GPS)  121.249794  feet  37.255099  -76.735947
# 8  61164.717861  Altitude (GPS)  121.249794  feet  37.255313  -76.736089
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 4         NaN
# 5         NaN
# 8         NaN

# %%
plt.rcParams["figure.figsize"] = (10,10)

figure, axis = plt.subplots(1, 1)
plot1 = plt.subplot2grid((1, 1), (0, 0), rowspan=1, colspan=1)
plot1.plot(df2['SECONDS'],df2['VALUE'])
