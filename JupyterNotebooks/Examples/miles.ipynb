# %%
total_miles = [11.4,8.7,5.5,7,7.7,9.1,7.2,1.3,9.6,13.9,6.2,5.6,7.6,6.9,7.1,7.3,8.4,7,9.1,5.8,5.4,6.1,6,3.3,6.7,5.4,3.5,1.7,1.9,0.88,2.6,2.3,3.6,4.8,5.9]
walked_miles = [4.5,5.4,3.1,4.0,3.2,3.5,4.4,0.0,6.4,5.1,4.1,3.5,3.5,4.6,2.5,6.1,5.6,3.9,5.4]
diff = [total_miles[i] - walked_miles[i] for i in range(len(walked_miles))]
#print(diff)

avg = sum(diff)/len(diff)

print(avg)

walked_miles_pred = [total_miles[i] - avg for i in range(len(total_miles))]
print(walked_miles_pred)
# Out:
# 3.568421052631579
# [7.831578947368421, 5.13157894736842, 1.931578947368421, 3.431578947368421, 4.131578947368421, 5.531578947368421, 3.6315789473684212, -2.268421052631579, 6.031578947368421, 10.33157894736842, 2.6315789473684212, 2.0315789473684207, 4.031578947368421, 3.3315789473684214, 3.5315789473684207, 3.731578947368421, 4.831578947368421, 3.431578947368421, 5.531578947368421, 2.231578947368421, 1.8315789473684214, 2.5315789473684207, 2.431578947368421, -0.2684210526315791, 3.1315789473684212, 1.8315789473684214, -0.06842105263157894, -1.868421052631579, -1.668421052631579, -2.688421052631579, -0.9684210526315788, -1.2684210526315791, 0.03157894736842115, 1.2315789473684209, 2.3315789473684214]

# %%
import matplotlib.pyplot as plt

plt.plot(walked_miles, label='Walked Miles')
plt.plot(walked_miles_pred, label='Predicted Walked Miles')

# %%
total_miles_December_20_thru_29 = [6.9,6.4,6.1,2.6,3.3,2.1,1.5,2.7,3.0,2.3]

base_miles_December_20_thru_29 = [1.7 for i in range(10)]

diff_December_20_thru_29 = [total_miles_December_20_thru_29[i] - base_miles_December_20_thru_29[i] for i in range(len(base_miles_December_20_thru_29))]

print(diff_December_20_thru_29)
print(sum(diff_December_20_thru_29))
# Out:
# [5.2, 4.7, 4.3999999999999995, 0.9000000000000001, 1.5999999999999999, 0.40000000000000013, -0.19999999999999996, 1.0000000000000002, 1.3, 0.5999999999999999]
# 19.9
