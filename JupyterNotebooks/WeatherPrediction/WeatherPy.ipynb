# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests, json
import time
from scipy.stats import linregress

# Import API key
#from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

dark_mode = True
# plotting choices for dark-mode ... comment out if not using dark mode!!!
if (dark_mode):
    from jupyterthemes import jtplot
    jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
    linecolor = 'w'
else:
    linecolor = 'k'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=20000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=20000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 3632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create a dataframe which will eventually hold all of the required raw data
raw_data = pd.DataFrame(columns =("City","Latitude","Longitude","Max Temp","Wind Speed","Cloudiness","Description", "Humidity"))

# %%
# Enter your API key here
api_key = "b9eda530467618ee7b488b14c39de25c"
  
# base_url variable to store url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

#loop
for city_name in cities:
  
    # complete_url variable to store
    # complete url address
    complete_url = base_url + "appid=" + api_key + "&q=" + city_name
  
    # get method of requests module
    # return response object
    response = requests.get(complete_url)
  
    # json method of response object 
    # convert json format data into
    # python format data
    x = response.json()
  
    # Now x contains list of nested dictionaries
    # Check the value of "cod" key is equal to
    # "404", means city is found otherwise,
    # city is not found
    if x["cod"] != "404":
  
        # store the value of "main"
        # key in variable y
        y = x["main"]
        y1 = x["wind"]
        y2 = x["clouds"]
        y3 = x["coord"]
  
        # store the value corresponding
        # to the "temp" key of y
        current_temperature = y["temp_max"]
  
        # store the value corresponding
        # to the "clouds" key of y
        current_clouds = y2["all"]
      
        # store the value corresponding
        # to the "humidity" key of y
        current_humidity = y["humidity"]
    
         # store the value corresponding
        # to the "wind" key of y
        current_wind = y1["speed"]
  
        # store the value of "weather"
        # key in variable z
        z = x["weather"]
        
        lat = y3["lat"]
        long = y3["lon"]
  
        # store the value corresponding 
        # to the "description" key at 
        # the 0th index of z
        weather_description = z[0]["description"]
  
        # print following values
        print(current_temperature, current_clouds, current_humidity, current_wind, weather_description, city_name, lat, long) 
        
        # create a dictionary 'tuple' containing the information that we want to put into the dataframe.
        # The advantage of using a dictionary here is that it is a nice, readable way to assocate the columns
        # in our dataframe with the variables that we have extracted from the json weather data THAT DOES NOT
        # DEPEND ON HOW WE ORDER THE DATA.
        row_to_add = {'City':city_name,'Latitude':lat,'Longitude':long,'Max Temp':current_temperature,'Cloudiness':current_clouds,'Wind Speed':current_wind,'Description':weather_description,'Humidity':current_humidity}
        
        # add this new row of data to the dataframe ... N.B.  the append() method of the DataFrame class is
        # immutable.  That is, calling this method does not, by itself, actually modify the dataframe.  Rather, it
        # RETURNS an object which is the modified dataframe.  So, we have to call the append() method, and then 
        # basically overwrite the original dataframe with this new modified dataframe.
        raw_data = raw_data.append(row_to_add, ignore_index = True)
   
        
    else:
        print(" City Not Found ")
# Out:
# 296.67 100 67 8.08 overcast clouds rikitea -23.1203 -134.9692
# 271.9 74 91 0.67 broken clouds pevek 69.7008 170.3133
# 285.37 100 83 2.24 light rain new norfolk -42.7826 147.0587
# 281.15 90 87 2.06 overcast clouds stromness 58.965 -3.296
# 291.15 1 32 2.06 clear sky albany 42.6001 -73.9662
# 297.7 45 77 0.74 scattered clouds jacareacanga -6.2222 -57.7528
# 294.12 3 77 3.55 clear sky arraial do cabo -22.9661 -42.0278
# 284.07 0 86 3.93 clear sky lebu -37.6167 -73.65
# 303.71 14 79 4.53 few clouds victoria 22.2855 114.1577
# 286.15 75 94 3 heavy intensity rain nikolskoye 59.7035 30.7861
# 286.6 0 23 4.75 clear sky mandalgovi 45.7625 106.2708
# 300.15 39 54 5.14 scattered clouds alyangula -13.8483 136.4192
# 283.15 100 46 3.6 overcast clouds aklavik 68.2191 -135.0107
# 289.15 1 29 3.09 clear sky jamestown 42.097 -79.2353
# 272.77 100 91 4.09 overcast clouds tiksi 71.6872 128.8694
# 301.59 64 73 4.25 light rain jian 27.1172 114.9793
# 279.15 20 70 2.06 few clouds ushuaia -54.8 -68.3
# 299.15 1 8 6.17 clear sky price 39.5994 -110.8107
# 293.15 1 42 3.09 clear sky wilmington 34.2257 -77.9447
# 295.93 2 32 5.36 clear sky baker city 44.7749 -117.8344
# 299.51 9 67 7.05 clear sky atuona -9.8 -139.0333
# 287.54 5 43 0.97 clear sky ak-dovurak 51.1833 90.6
# 267.15 40 68 3.6 scattered clouds longyearbyen 78.2186 15.6401
# 297.59 20 73 5.14 few clouds quatre cocos -20.2078 57.7625
# 274.26 90 37 16.09 overcast clouds san juan -31.5375 -68.5364
# 287.59 100 93 1.34 light rain kruisfontein -34.0033 24.7314
# 279.56 100 93 2.6 light rain zhigalovo 54.8097 105.1578
# 299.26 40 65 8.75 scattered clouds kapaa 22.0752 -159.319
#  City Not Found
# 297.59 40 56 4.63 scattered clouds cape canaveral 28.4058 -80.6048
# 291.15 75 32 0.71 broken clouds broome 42.2506 -75.833
# 297.59 0 67 2.24 clear sky grand gaube -20.0064 57.6608
# 284.26 72 75 1.79 broken clouds bluff -46.6 168.3333
# 294.96 77 95 0.95 broken clouds basoko 1.2391 23.616
# 287.09 83 76 2.77 broken clouds tokmak 47.2514 35.7058
# 298.15 75 94 5.14 mist kourou 5.1552 -52.6478
# 288.01 8 48 4.41 clear sky vostok 46.4856 135.8833
# 285.93 0 87 4.12 clear sky cape town -33.9258 18.4232
# 285.93 40 87 2.57 mist valparaiso -33.0393 -71.6273
# 288.15 0 55 8.23 clear sky alice springs -23.7 133.8833
# 303.15 40 62 3.6 light rain tautira -17.7333 -149.15
# 284.26 7 75 1.79 clear sky mataura -46.1927 168.8643
# 290.37 100 70 2.24 light rain busselton -33.65 115.3333
# 296.15 20 73 5.14 few clouds souillac -20.5167 57.5167
# 282.15 90 100 2.57 light rain prince rupert 54.3161 -130.3201
# 279.91 9 55 1.19 clear sky provideniya 64.3833 -173.3
# 280.15 90 100 5.14 light rain punta arenas -53.15 -70.9167
# 290.58 100 95 1.06 overcast clouds ribeira grande 38.5167 -28.7
# 301.15 75 83 4.12 broken clouds vaini -21.2 -175.2
# 298.12 55 85 4.19 broken clouds lethem 3.3803 -59.7968
# 287.15 53 67 5.14 broken clouds lompoc 34.6391 -120.4579
# 296.39 100 50 1.42 overcast clouds aragarcas -15.8975 -52.2508
# 302.59 20 89 1.54 few clouds georgetown 5.4112 100.3354
# 283.85 0 91 1.54 clear sky castro -24.7911 -50.0119
# 278.99 100 66 6.22 overcast clouds severo-kurilsk 50.6789 156.125
#  City Not Found
# 308.72 6 10 3.66 clear sky taoudenni 22.6783 -3.9836
#  City Not Found
# 275.15 20 80 5.14 few clouds tuktoyaktuk 69.4541 -133.0374
# 295.8 100 93 1.09 light rain kintampo 8.0563 -1.7306
# 296.88 55 80 4.36 broken clouds sambava -14.2667 50.1667
# 289.15 1 29 1.54 clear sky portage 41.1667 -81.1998
# 296.54 53 82 0.32 broken clouds aripuana -9.1667 -60.6333
# 294.91 100 76 1.12 overcast clouds alta floresta -9.8756 -56.0861
# 294.15 1 46 1.39 clear sky fergus falls 46.283 -96.0776
# 284.26 36 75 1.79 scattered clouds tuatapere -46.1333 167.6833
# 305.15 1 8 10.8 clear sky saint george 37.1041 -113.5841
# 306.18 84 11 1.88 broken clouds tessalit 20.1986 1.0114
#  City Not Found
# 293.36 1 78 0.81 clear sky sao joao da barra -21.6403 -41.0511
# 295.15 75 64 4.12 broken clouds shimoda 34.6667 138.95
#  City Not Found
#  City Not Found
# 284.26 1 43 4.12 clear sky nome 64.5011 -165.4064
# 287.64 100 66 3.92 overcast clouds port lincoln -34.7333 135.8667
# 286.15 40 71 2.06 scattered clouds superior 46.7208 -92.1041
#  City Not Found
# 290.15 100 39 1.03 overcast clouds goderich 43.7501 -81.7165
# 294.46 0 29 7.13 clear sky charters towers -20.1 146.2667
# 289.26 100 95 0.45 overcast clouds muros 42.7762 -9.0603
# 273.52 99 77 2.61 overcast clouds qaanaaq 77.484 -69.3632
# 285.1 100 80 7.76 overcast clouds jishui 33.7333 115.4
# 289.15 0 55 6 clear sky xinmin 41.9908 122.8253
# 306.15 0 38 1.54 clear sky doha 25.2867 51.5333
# 288.15 0 77 1.54 clear sky nola 40.922 14.5329
# 292.15 20 68 9.26 few clouds ponta do sol 32.6667 -17.1
# 288.15 75 63 8.23 broken clouds fallon 39.4735 -118.7774
# 289.15 0 44 2.06 clear sky komsomolskiy 40.4272 71.7189
# 272.72 14 95 1.99 few clouds egvekinot 66.3167 -179.1667
# 281.15 75 71 2.57 moderate rain kodiak 57.79 -152.4072
# 297.15 20 88 2.06 few clouds maceio -9.6658 -35.7353
# 270.15 16 80 1.03 few clouds tasiilaq 65.6145 -37.6368
# 287.15 75 67 1.54 broken clouds hauterive 46.0901 3.4459
# 286.46 99 96 3.72 overcast clouds podyuga 61.095 40.8647
# 299.26 75 78 1.03 broken clouds noumea -22.2763 166.4572
# 288.15 1 33 2.06 clear sky chapais 49.7834 -74.8492
#  City Not Found
# 286.15 0 76 1 clear sky mahdalynivka 48.921 34.9156
# 297.15 0 29 8.23 clear sky port hedland -20.3167 118.5667
# 300.15 75 74 4.63 broken clouds avarua -21.2078 -159.775
# 280.15 9 33 2.57 clear sky narsaq 60.9167 -46.05
# 293.12 84 60 1.85 broken clouds airai -8.9266 125.4092
#  City Not Found
# 297.15 40 100 1.03 scattered clouds hambantota 6.1241 81.1185
# 286.15 90 100 6.17 overcast clouds la ronge 55.1001 -105.2842
# 291.68 100 78 6.98 overcast clouds east london -33.0153 27.9116
# 292.15 76 59 5.14 broken clouds carnarvon -24.8667 113.6333
# 272.73 32 57 4.5 scattered clouds baykit 61.67 96.37
# 298.15 90 83 7.72 overcast clouds san patricio 28.017 -97.5169
# 303.17 97 68 4.58 light rain namatanai -3.6667 152.4333
# 277.59 75 100 1.54 light rain torbay 47.6666 -52.7314
# 289.64 81 23 5.05 broken clouds yumen 40.2833 97.2
# 301.46 38 79 6.96 light rain butaritari 3.0707 172.7902
# 296.15 0 68 3.6 clear sky saint-philippe -21.3585 55.7679
# 286.15 75 76 6.17 broken clouds port hardy 50.6996 -127.4199
# 298.29 100 94 0.71 overcast clouds gua musang 4.8823 101.9644
# 285.21 0 56 0.53 clear sky mvuma -19.2792 30.5283
# 263.24 100 91 5.87 overcast clouds saskylakh 71.9167 114.0833
# 269.15 75 74 3.6 light snow iqaluit 63.7506 -68.5145
# 265.08 98 90 4.52 overcast clouds khatanga 71.9667 102.5
# 302.15 20 84 1.03 few clouds beaufort 5.3473 115.7455
# 275.9 19 69 10 few clouds olafsvik 64.8945 -23.7142
# 290.1 92 88 7.36 moderate rain port alfred -33.5906 26.891
# 273.43 100 96 3.24 overcast clouds chokurdakh 70.6333 147.9167
# 288.88 0 46 3.06 clear sky zhezkazgan 47.8043 67.7144
# 292.15 0 88 8.23 clear sky nouadhibou 20.931 -17.0347
# 288.29 100 91 2.84 overcast clouds koygorodok 60.445 50.9968
#  City Not Found
# 279.15 75 81 2.57 broken clouds coihaique -45.5752 -72.0662
# 290.15 90 72 2.57 overcast clouds jefferson city 38.5767 -92.1735
# 288.15 90 100 1.54 moderate rain port elizabeth -33.918 25.5701
# 304.15 75 48 5.14 light rain hilo 19.7297 -155.09
# 300.93 92 100 2.16 light rain amahai -3.3333 128.9167
# 275.59 38 86 3.39 scattered clouds cherskiy 68.75 161.3
# 294.42 0 41 5.66 clear sky awjilah 29.1081 21.2869
# 279.15 90 87 8.75 overcast clouds klaksvik 62.2266 -6.589
# 300.15 20 83 2.57 few clouds the valley 18.217 -63.0578
# 287.48 100 50 2.48 overcast clouds huanren 41.2647 125.3667
# 285.37 100 82 0.89 overcast clouds hermanus -34.4187 19.2345
# 282.57 100 86 5.94 light rain kuytun 54.3419 101.5036
# 291.3 54 58 3.25 broken clouds sergeyevka 53.88 67.4158
#  City Not Found
# 272.6 97 94 2.86 overcast clouds leningradskiy 69.3833 178.4167
# 303.15 40 39 9.26 scattered clouds cabo san lucas 22.8909 -109.9124
# 265.15 1 62 4.12 clear sky clyde river 70.4692 -68.5914
# 271.84 99 87 2.88 overcast clouds upernavik 72.7868 -56.1549
# 301.72 1 68 4.43 clear sky sumenep -7.0167 113.8667
# 298.15 20 88 2.06 few clouds cotonou 6.3654 2.4183
# 291.81 5 83 3.83 clear sky huarmey -10.0681 -78.1522
# 288.71 100 93 2.24 overcast clouds lata 40.1629 -8.3327
# 276.58 100 90 3.18 overcast clouds ola 59.5833 151.2833
# 296.28 70 98 1.22 broken clouds daoukro 7.0591 -3.9631
# 285.93 78 90 2.71 light rain gora 51.6664 16.5349
#  City Not Found
# 297.15 75 100 2.79 light rain monrovia 6.3005 -10.7969
# 300.37 20 29 6.69 few clouds portland 45.5234 -122.6762
# 304.15 0 29 2.06 clear sky dagana 16.5165 -15.5068
# 288.15 100 66 2.24 overcast clouds mar del plata -38.0023 -57.5575
# 303.23 36 69 4.36 light rain buala -8.145 159.5921
# 298.15 75 94 5.14 light rain cayenne 4.9333 -52.3333
#  City Not Found
# 290.44 100 52 0.62 overcast clouds yaroslavskiy 44.1683 132.2072
# 301.72 22 37 3.22 few clouds surajgarh 28.3124 75.7347
# 266.17 42 89 1.06 scattered clouds tazovskiy 67.4667 78.7
# 294.15 6 37 10.8 clear sky geraldton -28.7667 114.6
# 287.06 75 75 2.22 light rain rio grande -32.035 -52.0986
# 291.15 40 29 3.6 scattered clouds sturgeon falls 46.3646 -79.9326
# 285.65 83 50 3.73 broken clouds rawson -43.3002 -65.1023
# 302.15 0 20 4.12 clear sky buraydah 26.326 43.975
# 295.15 20 94 3.09 fog pemba -12.974 40.5178
# 296.32 0 58 1.52 clear sky namibe -15.1961 12.1522
# 301.5 100 81 12.03 light rain kavaratti 10.5669 72.642
# 288.29 0 79 8.01 clear sky saldanha -33.0117 17.9442
# 288.71 40 82 5.66 scattered clouds fortuna 40.5982 -124.1573
# 279.15 97 87 1.03 light rain cap-aux-meules 47.3821 -61.8597
# 275.13 100 80 9.74 overcast clouds honningsvag 70.9821 25.9704
# 285.46 0 85 4.03 clear sky constitucion -35.3333 -72.4167
# 286.48 90 58 2.06 overcast clouds mildura -34.2 142.15
# 285.15 0 54 2.06 clear sky dalby -27.1833 151.2667
# 294.15 1 60 3.6 clear sky topeka 39.0483 -95.678
# 304.15 0 15 3.3 clear sky riyadh 24.6877 46.7219
# 274.08 17 91 2.01 few clouds lavrentiya 65.5833 -171
#  City Not Found
# 289.95 100 39 1.39 overcast clouds baishishan 43.5833 127.5667
# 287.53 100 91 5.21 light rain plettenberg bay -34.0527 23.3716
# 294.15 1 26 1.54 clear sky plainfield 40.6168 -74.4173
# 291.15 75 87 3.6 mist half moon bay 37.4636 -122.4286
#  City Not Found
#  City Not Found
# 293.01 4 74 4.23 clear sky tocopilla -22.092 -70.1979
# 281.15 75 87 2.06 broken clouds sindal 57.4712 10.2031
# 299.46 9 88 7.31 clear sky mogadishu 2.0371 45.3438
# 292.7 100 94 0.74 light rain tibati 6.4667 12.6333
# 282.87 100 90 2.26 overcast clouds leshukonskoye 64.8989 45.7622
# 291.15 19 55 3.09 few clouds shenavan 40.0549 43.9288
# 288.15 0 77 4 clear sky almaznyy 48.0448 40.045
# 296.15 0 94 2.57 clear sky pitimbu -7.4706 -34.8086
# 302.94 100 74 7.67 light rain kavieng -2.5744 150.7967
# 281.15 90 76 4.63 light rain sitka 57.0531 -135.33
# 299.55 65 79 6.71 broken clouds kilindoni -7.9139 39.6668
#  City Not Found
# 288.96 0 42 0.9 clear sky opuwo -18.0607 13.84
#  City Not Found
# 296.42 84 96 1.26 broken clouds guiglo 6.5456 -7.4966
#  City Not Found
# 297.15 75 43 4.12 broken clouds horn lake 34.9554 -90.0348
# 277.82 91 59 2.01 overcast clouds vestmannaeyjar 63.4427 -20.2734
# 299.15 75 73 2.11 broken clouds coahuayana 18.7333 -103.6833
# 280.26 8 55 1.6 clear sky batagay-alyta 67.8006 130.4114
# 299.2 33 84 1.34 scattered clouds bengkulu -3.8004 102.2655
# 289.26 0 46 1.79 clear sky flinders -34.5833 150.8552
# 265.05 79 92 3.57 broken clouds igarka 67.4667 86.5833
# 268.95 100 75 7.18 overcast clouds dikson 73.5069 80.5464
#  City Not Found
# 288.09 100 98 1.4 light rain metu 8.3 35.5833
# 302.15 40 74 7.72 scattered clouds hirara 24.8 125.2833
# 288.77 6 51 1.24 clear sky hwange -18.3693 26.5019
# 298.49 100 75 0.52 overcast clouds feijo -8.1642 -70.3536
# 270.15 90 80 5.14 haze barrow 71.2906 -156.7887
# 302.92 99 71 5.67 light rain dingle 10.9995 122.6711
# 299.57 37 85 3.88 scattered clouds soyo -6.1349 12.3689
# 302.45 0 38 7.46 clear sky khanpur 28.6453 70.6567
# 289.15 0 39 2.57 clear sky capaci 38.1711 13.2393
# 299.93 0 9 4.84 clear sky aswan 24.0934 32.907
# 291.15 100 52 4 overcast clouds trudovoye 43.3058 132.0817
# 301.5 100 83 0.69 light rain palu -0.8917 119.8707
# 284.82 3 59 2.31 clear sky kaitangata -46.2817 169.8464
# 262.72 92 95 1.99 overcast clouds pangnirtung 66.1451 -65.7125
# 297.5 78 81 7.51 broken clouds vao -22.6667 167.4833
# 285.15 92 82 3.09 overcast clouds bredasdorp -34.5322 20.0403
# 281.15 75 53 2.57 broken clouds thompson 55.7435 -97.8558
# 285.93 100 90 2.74 moderate rain krotoszyn 51.6987 17.4374
# 274.15 100 100 3.6 overcast clouds hay river 60.8156 -115.7999
# 301.64 92 71 6.05 overcast clouds jagtial 18.8 78.9333
# 300.91 100 80 1.73 overcast clouds banda aceh 5.5577 95.3222
# 292.79 85 80 1.45 overcast clouds linhares -19.3911 -40.0722
#  City Not Found
# 300.73 100 71 6.73 overcast clouds fare -16.7 -151.0167
# 289.53 99 84 1.86 overcast clouds serov 59.6033 60.5787
# 284.15 90 87 1.89 overcast clouds floro 61.5996 5.0328
# 294.42 91 76 2.22 light rain entebbe 0.0644 32.4469
# 297.15 20 94 1.54 few clouds touros -5.1989 -35.4608
# 298.15 20 88 2.57 few clouds lagos 6.5833 3.75
# 300.15 40 61 8.75 scattered clouds bathsheba 13.2167 -59.5167
# 293.41 100 98 1.02 light rain bozoum 6.3193 16.3799
# 294.15 75 83 9.77 broken clouds praia 14.9215 -23.5087
# 298.34 66 83 5.77 broken clouds bubaque 11.2833 -15.8333
# 302.76 17 71 2.29 light rain kieta -6.2167 155.6333
# 297.04 62 78 1.79 broken clouds hays 30.0502 -98.0336
# 271.98 100 60 3.56 overcast clouds aksarka 66.5606 67.7975
# 293.95 100 98 0.75 moderate rain bafia 4.75 11.2333
# 295.49 6 6 3.63 clear sky kutum 14.2 24.6667
# 286.15 75 62 7.2 broken clouds hobart -42.8794 147.3294
# 286.15 0 76 1 clear sky solone 48.2081 34.8721
# 296.15 40 31 3.09 scattered clouds pierre 44.3683 -100.351
# 290.93 0 51 0.89 clear sky port macquarie -31.4333 152.9167
# 296.48 1 43 3.09 clear sky laguna 38.421 -121.4238
# 302.15 20 74 2.57 few clouds isangel -19.55 169.2667
#  City Not Found
# 293.22 16 75 1.58 few clouds kaniama -7.5667 24.1833
# 278.75 100 95 10.82 overcast clouds vagur 61.4732 -6.8119
# 300.52 0 65 3.85 clear sky umm lajj 25.0213 37.2685
# 291.15 75 94 2.57 broken clouds vila franca do campo 37.7167 -25.4333
# 290.39 63 53 0.65 broken clouds diego de almagro -26.3667 -70.05
# 282.59 20 93 1.03 fog ancud -41.8697 -73.8203
# 296.48 100 64 2.24 light rain takahagi 36.7167 140.7167
# 300.15 75 65 7.2 broken clouds cristobal obregon 16.35 -93.5333
# 289.15 90 77 5.66 overcast clouds antofagasta -23.65 -70.4
# 288.15 75 100 4.12 mist wajima 37.4 136.9
# 297.9 100 94 0.7 overcast clouds mattru 7.6244 -11.8332
# 295.75 18 73 0.64 few clouds miandrivazo -19.5167 45.4667
# 297.59 1 67 2.24 clear sky cap malheureux -19.9842 57.6142
# 302.25 100 73 8.09 overcast clouds hithadhoo -0.6 73.0833
# 297.8 94 65 7.81 overcast clouds marsh harbour 26.5412 -77.0636
# 297.71 91 88 2.03 overcast clouds muisne 0.6 -80.0333
#  City Not Found
# 287.62 0 32 2.58 clear sky siyabuswa -25.1132 29.0445
# 298.44 100 59 0.53 overcast clouds urubicha -15.3833 -62.95
# 285.15 100 82 3.09 light rain swellendam -34.0226 20.4417
# 283.15 0 66 8.23 clear sky sistranda 63.7256 8.834
# 291.15 1 32 3.09 clear sky roma 43.2128 -75.4557
# 282.15 1 76 5.66 clear sky betsiamites 48.9413 -68.646
# 297.04 13 95 3.13 few clouds puerto ayora -0.7393 -90.3518
# 295.03 93 70 2.75 overcast clouds caravelas -17.7125 -39.2481
#  City Not Found
# 300.88 100 66 6.98 overcast clouds faanui -16.4833 -151.75
# 299.17 100 85 2.6 light rain bonthe 7.5264 -12.505
# 276.48 75 75 3.09 broken clouds yellowknife 62.456 -114.3525
#  City Not Found
# 289.26 100 57 3.71 overcast clouds pesaro 43.9036 12.8903
# 293.15 0 32 2.25 clear sky abha 18.2164 42.5053
# 277.15 0 60 4.63 clear sky grindavik 63.8424 -22.4338
# 299.82 40 47 7.72 scattered clouds venice 27.0998 -82.4543
# 301.42 5 71 3.92 clear sky pasni 25.2631 63.471
# 282.95 49 97 3.21 scattered clouds sobolevo 54.4299 31.8996
#  City Not Found
#  City Not Found
# 292.27 16 31 3.96 few clouds blackwater -23.5833 148.8833
# 286.52 100 76 7.11 overcast clouds codrington -38.2667 141.9667
# 299.34 100 89 2 light rain abonnema 4.7084 6.7931
#  City Not Found
# 300.15 20 74 5.14 few clouds kupang -10.1667 123.5833
# 302.15 75 78 6.69 broken clouds nishihara 26.1842 127.7558
# 302.45 10 72 4.21 clear sky jiazi 22.8779 116.067
# 294.26 14 75 2.68 few clouds kaeo -35.1 173.7833
# 301.15 0 83 1.03 clear sky abu dhabi 24.4667 54.3667
# 300.15 75 89 7.72 broken clouds naze 28.3667 129.4833
# 303.53 11 72 6.08 few clouds wanning 18.8003 110.3967
# 296.15 20 73 5.14 few clouds mahebourg -20.4081 57.7
# 289.11 100 76 1.8 light rain gondar 12.6 37.4667
# 290.42 100 36 3.71 moderate rain korla 41.7597 86.1469
# 301.92 90 71 4.45 overcast clouds tanete -3.9443 119.7848
# 292.15 1 34 1.54 clear sky bethel 41.3712 -73.414
# 298.15 75 94 0.51 broken clouds padang -0.9492 100.3543
# 295.15 75 40 7.2 broken clouds bloomington 44.8408 -93.2983
# 300.14 90 59 1.54 overcast clouds birao 10.2849 22.7882
# 293.71 7 78 1.34 clear sky muriwai beach -36.8167 174.45
# 292.04 0 59 1 light rain pekin 39.9075 116.3972
# 295.51 100 97 1.65 overcast clouds tongren 27.7172 109.1853
# 286.15 40 94 5.14 scattered clouds mount gambier -37.8333 140.7667
# 279.37 100 78 2.18 overcast clouds putina -15.4667 -69.4333
# 273.54 100 90 0.56 overcast clouds evensk 61.95 159.2333
# 272.19 100 61 7.47 overcast clouds yerbogachen 61.2767 108.0108
# 275.49 11 83 1.23 few clouds nanortalik 60.1432 -45.2371
# 301.15 20 69 2.57 few clouds loiza 18.4313 -65.8802
# 274.15 90 93 6.69 overcast clouds havoysund 70.9963 24.6622
# 291.82 10 54 1.35 clear sky kushmurun 52.4503 64.6311
# 286.12 23 36 6.08 few clouds kyra 49.5776 111.9753
# 292.15 1 39 1.54 clear sky southbury 41.4815 -73.2132
# 284.55 0 58 1.73 clear sky shu 43.5983 73.7614
# 287.45 0 76 2.31 clear sky kostyantynivka 48.5277 37.7069
# 286.47 2 89 1.62 clear sky mporokoso -9.3727 30.125
# 286.15 0 88 1.54 clear sky coquimbo -29.9533 -71.3436
# 286.84 100 63 1.31 overcast clouds olga 43.7444 135.2892
# 288.37 100 98 0.67 overcast clouds oxapampa -10.5775 -75.4017
# 301.56 0 77 9.28 clear sky bandarbeyla 9.4942 50.8122
# 284.26 100 99 0.45 light rain haverfordwest 51.8017 -4.9691
# 303.38 100 39 2.81 overcast clouds nohar 29.1833 74.7667
#  City Not Found
#  City Not Found
# 294.82 0 88 2.06 clear sky vila velha -20.3297 -40.2925
# 300.77 100 79 4.89 overcast clouds keti bandar 24.1447 67.4497
# 294.26 0 68 3.6 clear sky saint-pierre -21.3393 55.4781
# 274.15 90 93 2.57 light snow pechenga 69.5259 31.1703
# 293.15 0 60 1.54 clear sky cabra 37.4725 -4.4421
# 298.15 90 94 9.77 mist rockport 28.0206 -97.0544
# 288.2 29 49 4.58 scattered clouds flin flon 54.7682 -101.865
# 288.51 93 35 5.06 overcast clouds kysyl-syr 63.8986 122.7617
# 303.15 75 70 1.58 broken clouds puerto escondido 15.85 -97.0667
# 300.15 75 83 5 broken clouds guilin 25.2819 110.2864
# 275.15 75 69 2.06 broken clouds ilulissat 69.2167 -51.1
# 291.15 90 88 2.57 mist pisco -13.7 -76.2167
# 290.36 100 85 0.46 overcast clouds monteagudo -19.8167 -63.9833
# 302.68 2 70 6.86 clear sky laibin 23.7 109.2667
# 283.71 99 64 1.29 overcast clouds asau 46.4333 26.4
# 274.57 100 83 8.51 overcast clouds berlevag 70.8578 29.0864
# 293.15 40 30 5.14 scattered clouds swift current 50.2834 -107.8014
# 298.15 40 94 2.06 scattered clouds oussouye 12.485 -16.5469
# 302.6 18 70 4.11 few clouds tecoanapa 16.5167 -98.75
# 286.92 100 20 1.71 overcast clouds yinchuan 38.4681 106.2731
# 281.48 100 92 0.51 overcast clouds rena 61.1348 11.3641
# 287.19 100 45 1.01 overcast clouds shakawe -18.3667 21.85
# 286.48 90 82 1.54 overcast clouds port augusta -32.5 137.7667
# 284.82 57 46 2.78 broken clouds trelew -43.249 -65.3051
# 302.15 16 73 2.87 few clouds norsup -16.0667 167.3833
# 283.15 90 93 1.03 light rain jaromerice nad rokytnou 49.0941 15.8933
# 302.04 20 83 6.17 few clouds itoman 26.1247 127.6694
# 302.24 48 46 1.47 scattered clouds kaduqli 11.0167 29.7167
# 304.82 1 8 5.14 clear sky sunland park 31.7965 -106.58
# 274.33 100 93 8.4 snow vardo 70.3705 31.1107
#  City Not Found
# 301.84 31 81 4.67 scattered clouds alugan 12.2188 125.4808
# 298.05 100 92 1.73 overcast clouds owerri 5.4833 7.0304
# 273.41 100 97 5.32 overcast clouds ostrovnoy 68.0531 39.5131
# 298.15 1 57 3.6 clear sky longview 32.5007 -94.7405
# 294.5 99 75 8.01 overcast clouds paita -5.0892 -81.1144
# 298.03 100 84 0.36 moderate rain tutoia -2.7619 -42.2744
# 292.15 90 77 3.6 overcast clouds jasper 37.2001 -94.3502
# 290.55 100 56 2.75 overcast clouds santiago del estero -27.7951 -64.2615
# 302.15 75 79 3.09 broken clouds puerto barrios 15.7167 -88.6
# 300.45 25 80 1.72 scattered clouds metro -5.1131 105.3067
# 286.15 90 82 1.54 overcast clouds port pirie -33.1833 138.0167
# 297.81 100 85 3.49 overcast clouds itarema -2.9248 -39.9167
# 292.04 20 55 1.54 few clouds hamilton 39.1834 -84.5333
# 280.15 75 65 1.03 broken clouds port-cartier 50.0334 -66.8654
# 300.3 0 76 4.63 clear sky gondanglegi -7.7479 112.0132
#  City Not Found
# 290.02 65 25 1.47 broken clouds jiuquan 39.7432 98.5174
# 292.5 100 53 2.16 overcast clouds posse -14.0931 -46.3694
# 281.15 90 93 1.03 overcast clouds sandwick 60 -1.25
# 293.15 1 22 3.6 clear sky southbridge 42.0751 -72.0334
# 295.15 75 88 4.63 broken clouds shingu 33.7333 135.9833
# 294.88 98 55 2.81 overcast clouds moyale 3.5167 39.0584
# 299.14 88 87 2.95 overcast clouds mayumba -3.432 10.6554
# 294.3 100 96 0.33 overcast clouds businga 3.3333 20.8833
# 299.81 100 84 2.86 overcast clouds axim 4.8699 -2.2405
# 281.48 75 91 0.45 broken clouds yate 51.5407 -2.4184
# 297.15 1 60 2.15 clear sky russell 32.3502 -85.1999
#  City Not Found
#  City Not Found
# 302.04 100 70 7.15 overcast clouds antiguo morelos 22.5495 -99.0812
# 283.98 100 66 1.18 overcast clouds tacuarembo -31.7333 -55.9833
# 303.64 100 69 5.38 overcast clouds lorengau -2.0226 147.2712
# 292.15 75 72 6.17 broken clouds camacha 33.0833 -16.3333
# 285.15 28 82 5.66 scattered clouds esperance -33.8667 121.9
# 295.45 100 95 2.65 light rain yining 29.0361 114.5636
# 301.82 99 80 4.98 light rain balangiga 11.1097 125.3875
# 299.26 75 94 1.54 broken clouds aquiraz -3.9014 -38.3911
# 281.48 90 87 3.09 overcast clouds lillesand 58.2488 8.3778
# 300.97 99 75 2.21 overcast clouds puerto carreno 6.189 -67.4859
# 303.15 0 70 3 clear sky dayong 25.0209 118.2898
# 289.26 40 72 3.09 scattered clouds winona 43.9666 -91.7668
# 294.15 0 94 2.97 clear sky beira -19.8436 34.8389
# 285.28 100 77 1.46 overcast clouds linjiang 41.8069 126.9078
# 299.54 15 7 4.06 few clouds abeche 13.8292 20.8324
# 276.95 91 94 1 overcast clouds at-bashi 41.1702 75.8106
# 294.91 0 41 0.9 clear sky tiznit 29.5833 -9.5
# 303.15 40 79 5.66 scattered clouds acapulco 16.8634 -99.8901
# 292.85 0 65 5.17 clear sky kaspiyskiy 45.3929 47.3707
#  City Not Found
# 283.01 100 82 6.87 light rain novonukutskiy 53.7002 102.7117
# 290.15 75 34 4.63 broken clouds college 64.8569 -147.8028
# 281.15 90 93 2.57 overcast clouds skelleftea 64.7507 20.9528
# 298.15 1 53 5.66 clear sky durant 33.994 -96.3708
# 284.15 90 87 1.03 overcast clouds naujoji akmene 56.3167 22.9
# 287.15 71 67 1.03 broken clouds albanel 48.8832 -72.4487
# 298.61 100 89 2.87 overcast clouds gamba -2.65 10
# 284.68 99 79 1.69 overcast clouds chuy -33.6971 -53.4616
# 280.03 100 77 5.01 overcast clouds lokosovo 61.1333 74.8167
# 299.92 7 33 2.42 clear sky marzuq 14.4 46.4667
#  City Not Found
# 290.79 3 78 4.2 clear sky tukrah 32.5341 20.5791
# 297.59 20 73 5.14 few clouds bambous virieux -20.3428 57.7575
# 293.15 0 24 6.17 clear sky mount isa -20.7333 139.5
# 288.15 90 67 6.69 overcast clouds salinas 36.6777 -121.6555
# 289.25 29 73 3.81 scattered clouds shirochanka 46.6497 38.3978
# 290.15 20 39 5.14 few clouds thunder bay 48.4001 -89.3168
# 300.15 1 12 8.23 clear sky silver city 32.7701 -108.2803
# 286.5 7 49 2.05 clear sky shache 38.4167 77.2406
# 270.69 81 93 1.7 broken clouds deputatskiy 69.3 139.9
# 284.15 75 100 5.66 mist nemuro 43.3236 145.575
# 301.15 20 47 5.14 few clouds makakilo city 21.3469 -158.0858
# 279.48 100 57 3.98 overcast clouds magistralnyy 56.1725 107.4458
#  City Not Found
# 290.37 4 54 1.34 clear sky havelock 34.8791 -76.9013
#  City Not Found
# 292.33 0 35 2.68 clear sky richards bay -28.783 32.0377
# 287.75 0 73 2.8 clear sky sao luiz gonzaga -28.4083 -54.9608
# 297.04 0 32 8.48 clear sky karratha -20.7377 116.8463
# 295.02 100 98 0.7 overcast clouds boende -0.2167 20.8667
# 281.15 90 93 1.03 overcast clouds brae 60.3964 -1.353
# 283.35 100 79 7.25 light rain tyret pervaya 53.6703 102.3106
# 289.51 1 77 3.12 clear sky cidreira -30.1811 -50.2056
# 300.17 85 77 2.84 overcast clouds kroya -7.6331 109.2461
# 286.07 90 89 2.73 overcast clouds terny 50.9833 33.9833
# 295.91 100 87 4.02 overcast clouds kabo 7.6994 18.629
# 290.34 8 44 3.09 clear sky staraya poltavka 50.4772 46.4814
#  City Not Found
# 277.15 75 81 2.57 broken clouds nuuk 64.1835 -51.7216
# 295.14 3 57 3.57 clear sky zhongshu 24.5167 103.7667
#  City Not Found
# 279.82 100 98 1.29 overcast clouds soderhamn 61.3037 17.0592
# 300.17 69 76 1.8 broken clouds gombong -7.6072 109.5142
# 280.93 92 87 0.94 overcast clouds oyon -10.6681 -76.7731
# 283.71 19 89 5.39 few clouds stekene 51.2148 4.0335
# 299.25 78 88 2.88 broken clouds pizarro 4.9533 -77.366
# 290.37 82 91 4.02 broken clouds peniche 39.3558 -9.3811
# 284.82 47 96 2.38 scattered clouds mercedes -34.6515 -59.4307
# 293.15 0 77 7.72 clear sky los llanos de aridane 28.6585 -17.9182
# 277.15 90 81 1.03 overcast clouds storsteinnes 69.2408 19.2344
# 301.15 75 78 3.09 broken clouds champerico 14.3 -91.9167
# 281.9 8 90 2.77 clear sky zbarazh 49.6636 25.7762
# 299.32 100 74 4.78 overcast clouds panaba 21.2833 -88.2667
# 287.1 86 86 2.74 overcast clouds ginir 7.1333 40.7
# 291.33 100 41 6.32 overcast clouds fujin 47.26 132.0322
# 305.37 20 50 2.4 haze niwari 28.8833 77.5333
# 294.76 98 96 0.9 overcast clouds tocache -8.1842 -76.5125
#  City Not Found
# 293.36 0 88 4.57 clear sky inhambane -23.865 35.3833
# 290.93 86 45 0.45 overcast clouds novyye burasy 52.1324 46.0714
# 304.82 20 66 3.6 few clouds santa rosa 14.3122 121.1114
# 287.24 84 97 1.27 broken clouds butembo 0.15 29.2833
# 283.15 0 87 0.42 clear sky oskemen 49.9565 82.6119
# 300.15 40 73 9.77 scattered clouds alice 27.7523 -98.0697
# 295.93 1 64 3.09 clear sky houma 29.5958 -90.7195
# 303.15 40 70 1.54 haze port moresby -9.4431 147.1797
# 299.15 99 25 3.6 overcast clouds glenwood springs 39.5505 -107.3248
# 298.13 68 55 0.56 broken clouds san matias -16.3667 -58.4
# 282.15 20 76 6.17 few clouds kenai 60.5544 -151.2583
# 280.37 100 94 0.54 light rain tonstad 58.6626 6.7169
# 303.27 33 66 1.64 scattered clouds auki -8.7676 160.7034
# 297.04 75 60 6.17 moderate rain hasaki 35.7333 140.8333
# 283.15 0 66 4.12 clear sky comodoro rivadavia -45.8667 -67.5
# 301.15 20 51 11.32 few clouds lahaina 20.8783 -156.6825
#  City Not Found
# 294.1 82 95 0.91 broken clouds utete -7.986 38.758
# 288.33 100 79 2.56 overcast clouds severnoye 56.3491 78.3619
# 301.1 32 67 6.4 scattered clouds waingapu -9.6567 120.2641
# 301.15 40 89 1.54 scattered clouds tarakan 3.3 117.6333
# 292.67 1 67 4.74 clear sky ahipara -35.1667 173.1667
# 285.15 40 82 2 light rain bograd 54.2344 90.8328
# 299.15 40 78 3.09 scattered clouds cockburn town 21.4612 -71.1419
# 291.87 0 45 1.24 clear sky sidi ali 36.0998 0.4206
# 306.72 61 29 0.78 broken clouds garautha 25.5667 79.3
# 288.15 0 72 1.54 clear sky walvis bay -22.9575 14.5053
# 268.6 18 69 2.23 few clouds krasnoselkup 65.7 82.4667
# 272.38 91 88 0.36 overcast clouds macusani -14.0833 -70.4333
# 286.44 100 92 3.72 overcast clouds negrasi 44.6 25.1167
# 282.2 100 35 5.41 overcast clouds dongsheng 39.8161 109.9776
# 287.03 100 96 2.54 overcast clouds pudozh 61.8099 36.5345
#  City Not Found
# 298.92 94 75 5.9 overcast clouds poum -20.2333 164.0167
# 301.35 17 75 1.4 few clouds palas -5.6519 105.6801
# 296.84 100 95 1.52 overcast clouds prainha -1.8 -53.48
# 302.84 98 18 2.69 overcast clouds maine-soroa 13.2114 12.0241
# 291.15 40 94 3.01 scattered clouds praia da vitoria 38.7333 -27.0667
# 280.37 19 87 5.66 few clouds laupheim 48.2333 9.8833
#  City Not Found
#  City Not Found
# 287.1 5 65 1.59 clear sky kasempa -13.4584 25.8338
# 297.15 0 31 7.72 clear sky kununurra -15.7667 128.7333
# 302.36 100 73 0.85 overcast clouds simbahan 6.3032 120.5836
# 289.82 100 67 1.34 overcast clouds virden 39.5009 -89.7679
# 291.33 61 79 6.48 broken clouds suluq 31.6682 20.2521
# 293.71 0 42 6.69 clear sky mackay -21.15 149.2
# 297.85 96 71 2.72 overcast clouds kouroussa 10.65 -9.8833
# 281.8 97 95 1.84 overcast clouds tralee 52.2704 -9.7026
# 276.36 5 77 3.87 clear sky srednekolymsk 67.45 153.6833
# 285.05 0 63 2.47 clear sky rusape -18.5278 32.1284
# 298.6 81 90 2.21 moderate rain omboue -1.5746 9.2618
# 295.93 75 64 6.69 light rain katsuura 35.1333 140.3
# 280.15 90 76 3.6 overcast clouds havre-saint-pierre 50.2334 -63.5986
# 284.82 100 100 1.54 fog maldonado -34.6667 -54.9167
# 286.69 3 61 0.75 clear sky yozgat 39.5833 35.3333
# 295.28 100 99 0.82 overcast clouds amapa 1 -52
# 287.04 100 1 0.89 light rain zhoucheng 35.9122 116.3117
# 285.93 0 100 1.54 clear sky keuruu 62.2667 24.7
# 289.26 0 100 1.03 clear sky tricase 39.9304 18.3553
# 300.09 100 83 0.96 overcast clouds jaque 7.5175 -78.1703
# 301.15 90 83 4.63 overcast clouds kloulklubed 7.0419 134.2556
# 300.42 8 75 3.22 clear sky bambanglipuro -7.95 110.2833
# 289.45 52 88 2.57 broken clouds mgandu -5.95 34.1333
# 287.28 4 19 1.88 clear sky baruun-urt 46.6806 113.2792
# 283.15 0 81 2.06 clear sky saint-francois 46.4154 3.9054
# 302.15 20 58 2.06 few clouds ixtapa 20.7 -105.2
#  City Not Found
# 287.13 5 62 0.36 clear sky zyryanovsk 49.7386 84.2719
# 289.82 0 67 0.51 clear sky quartucciu 39.2519 9.1794
# 294.15 40 88 0.51 scattered clouds bangui 4.3612 18.555
# 303.15 40 70 2 scattered clouds dongli 23.5656 116.8194
# 304.15 40 70 7.2 scattered clouds bairiki 1.3292 172.9752
# 289.15 75 100 3.6 broken clouds betanzos 43.2804 -8.2147
# 301.41 37 81 1.9 scattered clouds teknaf 20.8624 92.3058
# 300.15 40 89 0.51 scattered clouds port blair 11.6667 92.75
# 290.43 0 84 3.21 clear sky henties bay -22.116 14.2845
# 295.76 62 96 0.35 broken clouds contamana -7.3333 -75.0167
# 292.15 1 37 2.33 clear sky carroll 39.5501 -77.0164
# 291.15 0 36 4.63 clear sky bundaberg -24.85 152.35
# 292.15 75 34 2.06 broken clouds brantford 43.1334 -80.2664
# 301.52 0 64 0.88 clear sky panarukan -7.7018 113.9184
# 292.39 33 90 1.18 scattered clouds masuguru -11.3667 38.4167
# 277.93 100 91 3.73 light rain nyurba 63.2842 118.3319
# 295.15 0 23 1.13 clear sky dahra 36.2546 0.8519
# 304.15 75 79 2.06 broken clouds sola -13.8833 167.55
# 285.93 0 65 4.02 clear sky dunedin -45.8742 170.5036
# 301.15 4 74 5.14 clear sky alofi -19.0595 -169.9187
#  City Not Found
# 303.15 40 62 3.6 light rain papetoai -17.4961 -149.8729
#  City Not Found
# 285.06 95 78 1.69 overcast clouds santa vitoria do palmar -33.5189 -53.3681
# 274.16 100 92 5.56 light snow noyabrsk 63.1994 75.4507
#  City Not Found
# 287.15 5 54 6.69 clear sky yulara -25.2406 130.9889
# 301.86 89 71 1.74 overcast clouds manokwari -0.8667 134.0833
# 264.99 98 92 1.84 light snow talnakh 69.4865 88.3972
# 295.93 100 97 1.02 light rain cururupu -1.8283 -44.8683
# 283.71 98 89 0.89 overcast clouds dungarvan 52.0881 -7.6253
# 274.27 100 97 0.99 overcast clouds olenegorsk 68.15 33.3
# 286.55 19 43 0.55 few clouds sar-e pul 35.8333 66.1667
# 288.36 0 73 1.87 clear sky kreminna 49.0495 38.2179
# 298.18 100 84 3.77 overcast clouds acarau -2.8856 -40.12
# 295.69 99 67 0.5 overcast clouds mangan 27.5167 88.5333
# 301.14 100 82 5.08 overcast clouds galle 6.0367 80.217
# 295.98 100 52 1.39 overcast clouds niquelandia -14.4739 -48.4597
# 287.59 85 93 1.99 overcast clouds kibaya -5.3 36.5667
# 286.07 95 63 1.32 overcast clouds jumla 29.2747 82.1838
# 301.15 1 26 6.17 clear sky jackson 42.4165 -122.8345
# 284.15 75 46 7.72 broken clouds norman wells 65.282 -126.8329
# 280.37 100 100 2.24 overcast clouds asnaes 55.8123 11.5013
# 286.15 0 88 1.54 clear sky la serena -29.9078 -71.2542
# 294.26 0 68 3.6 clear sky saint-joseph -21.3667 55.6167
#  City Not Found
# 295.15 1 24 3.09 clear sky sylvan lake 52.3168 -114.0853
# 290.93 99 63 2.57 overcast clouds winnipeg 49.8844 -97.147
# 296.95 97 77 0.72 overcast clouds campo maior -4.8278 -42.1686
# 292.59 65 84 1.53 broken clouds presidencia roque saenz pena -26.7852 -60.4388
# 301.19 94 83 2.39 overcast clouds luwuk -0.9516 122.7875
# 301.15 20 83 1.54 few clouds semporna 4.4818 118.6112
#  City Not Found
# 300.93 49 73 0.45 scattered clouds upata 8.0086 -62.3989
# 292.66 61 67 7.77 broken clouds asfi 32.2994 -9.2372
# 299.48 68 81 3.72 broken clouds boyolangu -8.1181 111.8935
# 285.15 0 94 1.03 clear sky talcahuano -36.7167 -73.1167
# 263.21 95 94 2.55 overcast clouds dudinka 69.4058 86.1778
#  City Not Found
# 288.15 75 41 2.06 broken clouds high level 58.5169 -117.136
# 293.15 90 63 10.8 overcast clouds nipawin 53.3668 -104.0009
# 295.22 59 33 2.34 broken clouds garmsar 35.2182 52.3409
# 294.43 36 65 1.21 scattered clouds manono -7.3 27.4167
# 282.15 90 81 5.14 light rain juneau 58.3019 -134.4197
# 299.15 40 89 2 scattered clouds mersing 2.4312 103.8405
# 292.16 100 60 1.03 overcast clouds cavalcante -13.7975 -47.4583
# 299.15 75 100 0.45 fog huai yot 7.7893 99.6348
# 299.15 40 100 2.56 light rain mbini 1.574 9.6134
# 296.51 100 14 3.8 overcast clouds hami 42.8 93.45
# 281.15 90 100 3.09 overcast clouds skoghall 59.3232 13.4655
# 288.71 98 80 1.82 overcast clouds sant julia de loria 42.4625 1.4825
# 295.04 9 74 1.68 clear sky torit 4.4133 32.5678
# 283.79 100 42 10.11 overcast clouds zhigansk 66.7697 123.3711
# 294.15 1 28 1.54 clear sky dobson 36.3957 -80.7226
# 285.58 100 96 2.98 overcast clouds iwanai 42.9744 140.5089
# 275.57 100 62 1.74 overcast clouds kargil 34.5667 76.1
# 302.59 84 75 1.79 broken clouds pochutla 15.7432 -96.4661
# 299.15 20 94 1.54 few clouds kuala terengganu 5.3302 103.1408
# 298.04 100 80 2.63 overcast clouds kontagora 10.3999 5.4695
#  City Not Found
# 276.48 92 87 0.51 overcast clouds bonavista 48.6499 -53.1147
# 298.64 100 86 1.49 overcast clouds meulaboh 4.1363 96.1285
# 299.15 75 94 2.06 broken clouds alenquer -1.9417 -54.7383
# 303.15 20 70 3.09 few clouds nha trang 12.25 109.1833
# 284.49 100 45 2.3 overcast clouds tigil 57.8 158.6667
# 292.91 25 64 2.15 scattered clouds paramirim -13.4425 -42.2389
# 294.99 0 37 5.85 clear sky jalu 29.0331 21.5482
# 294.37 92 71 7.68 overcast clouds sechura -5.5569 -80.8222
# 295.65 86 89 2.49 light rain mananara -16.1667 49.7667
# 290.95 4 65 3.32 clear sky misratah 32.3754 15.0925
# 304.94 1 9 2.23 clear sky bilma 18.6853 12.9164
# 292.69 0 27 7.27 clear sky seydi 39.4816 62.9137
# 298.15 20 88 2.06 few clouds porto novo 6.4965 2.6036
# 283.38 89 97 3.6 overcast clouds arkhangelskoye 55.8549 35.3287
# 297.77 6 77 3.72 clear sky tamandare -8.7597 -35.1047
# 291.54 3 76 2.42 clear sky taltal -25.4 -70.4833
# 299.58 55 61 1.97 broken clouds atambua -9.1061 124.8925
# 296.4 93 95 0.38 overcast clouds canutama -6.5339 -64.3831
# 287.59 0 47 8.75 clear sky nelson bay -32.7167 152.15
# 301.75 100 55 7.53 overcast clouds buldana 20.5333 76.1833
# 302.15 0 32 2.06 clear sky minab 27.1467 57.0801
# 290.15 90 36 6.69 light rain waverly 42.7392 -84.6208
# 293.63 6 76 1.68 clear sky kabinda -6.1333 24.4833
# 289.82 0 87 3.09 light rain cordoba -31.4135 -64.1811
# 283.8 100 98 2.1 overcast clouds luga 58.7372 29.8453
# 278.15 90 87 8.75 overcast clouds andenes 69.3143 16.1194
# 304.04 66 58 1.3 broken clouds thayetmyo 19.3167 95.1833
#  City Not Found
# 295.66 99 52 1.54 overcast clouds alto araguaia -17.3147 -53.2153
# 289.16 36 90 2 scattered clouds luderitz -26.6481 15.1594
# 289.82 6 83 1.77 clear sky kropotkin 45.4375 40.5756
# 294.15 0 60 3.09 clear sky porecatu -22.7558 -51.3792
# 299.78 86 68 0.52 overcast clouds son la 21.3167 103.9
# 302.49 6 42 2.37 clear sky mansa 29.9833 75.3833
# 297.96 100 78 2.74 light rain moerai -22.4333 -151.3333
# 278.71 20 87 2.06 few clouds torphins 57.1056 -2.624
# 283.19 100 75 1.55 overcast clouds rocha -34.4833 -54.3333
# 290.15 90 39 6.17 overcast clouds traverse city 44.7631 -85.6206
# 297.15 1 35 1.54 clear sky alabaster 33.2443 -86.8164
# 291.15 1 36 4.63 clear sky hervey bay -25.2986 152.8535
# 289.52 0 58 2 clear sky krasnoyarka 55.3333 73.1167
# 289.5 100 84 3.59 overcast clouds rudnichnyy 59.617 52.4703
#  City Not Found
# 291.44 97 66 3.24 overcast clouds verkhnyaya sinyachikha 57.976 61.6673
# 303.84 77 66 2.15 broken clouds lala 7.9745 123.7458
# 298.15 20 88 1.54 light rain luba 3.4568 8.5547
# 273.01 8 86 1.41 clear sky tilichiki 60.4667 166.1
#  City Not Found
#  City Not Found
# 293.71 21 38 2.09 few clouds port washington 40.8257 -73.6982
# 279.82 64 83 0.45 broken clouds hajnowka 52.7433 23.5812
# 284.05 0 95 3.5 clear sky ustyuzhna 58.8394 36.4321
# 283.71 100 100 3.6 moderate rain roald 62.5833 6.1333
# 276.97 31 73 3.48 scattered clouds usinsk 65.9939 57.5281
# 296.9 88 85 2 overcast clouds tura 25.5198 90.2201
# 276.07 100 95 4.44 overcast clouds magadan 59.5667 150.8
# 290.25 100 71 2.73 overcast clouds abalak 58.1286 68.5944
# 282.04 100 97 1.47 light rain ustek 50.5847 14.3433
# 281.15 75 76 3.09 broken clouds rio gallegos -51.6226 -69.2181
# 287.75 37 76 1.71 scattered clouds rtishchevo 52.2604 43.7874
# 287.7 98 88 1.74 light rain akcakoca 41.0866 31.1162
# 299.15 40 94 2.06 scattered clouds kabanjahe 3.1001 98.4908
# 287.59 3 60 2.35 clear sky aleksandro-nevskiy 53.4751 40.2095
#  City Not Found
# 298.15 20 88 0.51 few clouds kinkala -4.3614 14.7644
# 299.83 96 22 2.7 overcast clouds atar 20.5169 -13.0499
# 295.4 5 81 1.69 clear sky morondava -20.2833 44.2833
# 293.18 100 79 0.19 overcast clouds along 28.1667 94.7667
# 303.65 100 72 2.06 overcast clouds chinchani 19.8667 72.7
# 291.98 9 73 1.33 clear sky nsanje -16.92 35.262
# 296.15 0 68 3.6 clear sky saint-leu -21.15 55.2833
# 293.15 0 30 6 clear sky aktau 43.65 51.2
# 302.99 13 14 3.14 few clouds goure 13.9835 10.2704
# 272.54 100 98 3.51 overcast clouds kautokeino 69.0125 23.0412
# 299.43 100 84 2.5 overcast clouds harper 4.375 -7.7169
# 283.15 0 87 1 clear sky podgornoye 51.735 39.1496
# 295.2 100 99 1.68 overcast clouds capitao poco -1.7464 -47.0594
# 289.98 0 67 8.51 clear sky guerrero negro 27.9769 -114.0611
#  City Not Found
# 293.15 100 90 1.15 overcast clouds erzin 36.9559 36.2
# 297.47 97 73 1.16 overcast clouds guayaramerin -10.8368 -65.3614
# 293.81 0 81 2.09 clear sky ambilobe -13.2 49.05
# 286.69 100 58 2.04 overcast clouds san luis -33.295 -66.3356
# 294.15 1 40 3.09 clear sky saint anthony 45.0205 -93.218
# 289.82 0 82 1.06 clear sky gat 31.61 34.7642
# 273.05 100 91 3.54 overcast clouds aasiaat 68.7098 -52.8699
# 301.15 20 51 11.32 few clouds kahului 20.8947 -156.47
# 298.76 100 89 2.05 overcast clouds lokoja 7.8024 6.743
# 294.15 0 83 6.17 clear sky nouakchott 18.0858 -15.9785
# 289.26 3 42 1.18 clear sky batemans bay -35.7167 150.1833
# 287.15 0 72 3.09 clear sky rio cuarto -33.1307 -64.3499
# 284.15 90 54 5.66 overcast clouds broken hill -31.95 141.4333
# 285.15 89 43 7 overcast clouds smolenka 52.1352 113.4974
# 288.8 14 95 3.71 few clouds aljezur 37.3191 -8.8033
# 275.15 90 64 4.63 overcast clouds husavik 66.0449 -17.3389
# 282.15 20 71 5.14 few clouds homer 59.6425 -151.5483
# 296.15 6 28 3.6 clear sky katherine -14.4667 132.2667
# 288.86 52 91 1.35 broken clouds minas novas -17.2186 -42.5903
# 279.26 88 88 1.78 overcast clouds lasa 46.6166 10.7002
# 283.6 6 64 2.47 clear sky te anau -45.4167 167.7167
# 289.15 90 77 3.6 overcast clouds kirksville 40.1948 -92.5833
# 290.01 6 69 7 clear sky san quintin 30.4833 -115.95
# 298.9 53 82 3.1 broken clouds emilio carranza 19.9711 -96.6114
# 303.15 100 99 6.41 overcast clouds nueva gorgona 8.55 -79.8667
#  City Not Found
# 281.15 0 87 1.99 clear sky neuquen -38.9516 -68.0591
# 287.64 100 96 2.17 overcast clouds vizinga 61.0749 50.1031
# 284.26 100 86 1.75 light rain kitimat 54.0524 -128.6534
# 276.64 100 96 3.56 light snow lensk 60.7253 114.9278
# 288.15 100 51 2.24 overcast clouds mussomeli 37.5778 13.7513
# 296.48 99 64 2.24 overcast clouds iwaki 37.05 140.8833
# 286.15 0 62 2.06 clear sky keetmanshoop -26.5833 18.1333
# 298.15 1 47 4.12 clear sky mango 27.9797 -82.3065
# 287.15 100 30 6 overcast clouds petropavlovsk-kamchatskiy 53.0452 158.6483
#  City Not Found
# 297.53 93 86 2.19 overcast clouds chhatak 25.0333 91.6667
# 299.96 100 18 4.59 overcast clouds adrar 20.5022 -10.0711
# 300.41 0 77 2.51 clear sky labuhan -6.8844 112.2051
# 281.59 100 69 10.53 moderate rain kurilsk 45.2333 147.8833
# 285.89 24 50 4.93 few clouds queenstown -31.8976 26.8753
# 285.24 100 92 2.92 overcast clouds bakchar 57.0186 82.0711
# 284.73 84 76 9.12 broken clouds poronaysk 49.2167 143.1167
# 300.01 93 82 2.94 overcast clouds biak -0.9131 122.8766
# 297 100 95 1.6 overcast clouds almeirim -1.5233 -52.5817
#  City Not Found
# 288.71 71 62 4.63 broken clouds seddon -37.8068 144.8916
# 301.15 20 83 2.57 few clouds miri 4.4148 114.0089
# 285.93 84 65 0.45 broken clouds tandil -37.3217 -59.1332
# 296.18 100 97 2.88 moderate rain sao caetano de odivelas -0.75 -48.02
# 279.15 3 70 1.54 clear sky bloemfontein -29.1211 26.214
# 307.15 40 43 5.66 scattered clouds el rosario 24.2556 -107.1828
# 303.39 14 67 3.3 few clouds bac lieu 9.285 105.7244
# 281.84 100 83 9.47 moderate rain yuzhno-kurilsk 44.0306 145.8556
# 289.35 100 88 2.77 overcast clouds lagoa 39.05 -27.9833
# 293.15 0 32 2.12 clear sky faya 18.3851 42.4509
#  City Not Found
# 286.15 75 94 3 moderate rain maloye verevo 59.6136 30.1728
# 303.11 5 69 3.26 clear sky kirakira -10.4544 161.9205
# 303.05 49 23 1.09 scattered clouds tahoua 14.8888 5.2692
# 302.81 7 68 0.51 clear sky qui nhon 13.7667 109.2333
# 301.01 97 79 5.68 overcast clouds merauke -8.4667 140.3333
# 295.36 13 83 1.84 few clouds juba 4.8517 31.5825
# 284.15 40 87 4.63 scattered clouds saint stephen 50.3333 -4.9
# 299.15 40 57 6.69 scattered clouds stillwater 36.1156 -97.0584
# 292.59 1 72 2.14 clear sky mount pleasant 32.7941 -79.8626
# 274.22 79 81 0.79 broken clouds bilibino 68.0546 166.4372
#  City Not Found
# 305.37 51 69 1.24 broken clouds marawi 7.9986 124.2928
# 294.15 1 40 2.06 clear sky waycross 31.2136 -82.354
# 303.62 72 39 3.61 broken clouds marabba 12.35 32.1833
# 292.15 100 30 3.6 overcast clouds ferme-neuve 46.7001 -75.4493
# 273.35 100 95 4.14 overcast clouds beringovskiy 63.05 179.3167
# 299.39 100 84 2.28 overcast clouds tabou 4.423 -7.3528
# 288.8 96 94 1.84 overcast clouds la sierra 2.1784 -76.7626
#  City Not Found
# 303.8 100 70 2.32 overcast clouds dahanu 19.9667 72.7333
# 294.15 75 43 3.09 broken clouds miraflores 19.2167 -98.8083
# 284.26 11 91 2.24 few clouds portsmouth 50.799 -1.0913
# 301.9 8 76 3.98 clear sky jieshi 22.8134 115.8257
# 287.65 0 39 2.91 clear sky kang -23.6752 22.7876
# 284.26 95 88 0.71 overcast clouds lana 46.6124 11.1559
# 287.15 90 82 2.06 overcast clouds rapid valley 44.0625 -103.1463
# 290.15 75 72 9.77 broken clouds waipawa -41.4122 175.5153
# 300.15 20 78 0.29 few clouds mae ramat 16.984 98.5166
# 280.37 90 100 2 fog svetlyy 54.675 20.1347
# 299.15 40 78 1.54 scattered clouds chazuta -6.5742 -76.1367
# 292.15 20 34 1.03 few clouds shelburne 44.0787 -80.2041
# 280.27 100 77 4.95 overcast clouds verkhnevilyuysk 63.4453 120.3167
# 299.15 40 78 3.09 scattered clouds la romana 18.4273 -68.9728
# 276.38 100 89 8.59 light rain okhotsk 59.3833 143.3
# 295.85 100 98 1.15 overcast clouds lagunas -5.2269 -75.6753
#  City Not Found
# 274.15 90 93 1.03 light rain oksfjord 70.2396 22.3479
# 300.15 0 22 6.69 clear sky safaga 26.7292 33.9365
# 291.22 69 49 1.25 broken clouds sayyan 15.1718 44.3244
# 286.42 100 97 3.24 moderate rain savinskiy 62.9342 40.1361
#  City Not Found
#  City Not Found
# 289.82 0 82 2.57 clear sky torrijos 39.9819 -4.2835
# 287.6 97 92 3.41 light rain gornopravdinsk 60.05 69.9
# 293.34 85 57 0.71 overcast clouds arinos -15.9169 -46.1056
# 286.48 80 89 3.73 broken clouds pacific grove 36.6177 -121.9166
# 300.19 100 86 3.9 overcast clouds weligama 5.9667 80.4167
# 286.15 0 62 1.54 clear sky upington -28.4478 21.2561
# 303 56 71 4.04 broken clouds balabac 7.9868 117.0645
# 300.34 83 72 1.44 broken clouds fomboni -12.28 43.7425
# 274.44 100 97 4.69 light snow muravlenko 63.7898 74.523
# 288.72 95 95 2.27 light rain sharanga 57.1775 46.5396
# 300.49 100 74 1.57 overcast clouds pailitas 8.9565 -73.6255
# 301.15 4 47 2.06 haze rohri 27.6922 68.8951
# 293.15 0 83 5.14 clear sky idlib 35.9306 36.6339
# 292.18 9 79 5.26 clear sky san pedro de lloc -7.4328 -79.5058
# 299.12 97 96 0.71 overcast clouds ha giang 22.8333 104.9833
# 292.3 96 53 3.39 overcast clouds makushino 55.2103 67.2442
# 299.48 100 68 1.04 overcast clouds san carlos 9.6612 -68.5827
# 293.15 75 82 1.03 broken clouds florianopolis -27.6146 -48.5012
#  City Not Found
# 282.59 100 100 5.36 light rain zatec 50.3272 13.5458
# 288.83 86 65 1.05 overcast clouds san vicente -26.6167 -54.1333
# 293.15 90 15 8.23 overcast clouds bud 39.447 -86.1758
#  City Not Found
# 299.26 1 57 7.2 clear sky country club 25.9482 -80.317
#  City Not Found
# 289.23 9 37 2.01 clear sky chiredzi -21.05 31.6667
# 281.28 0 56 0.39 clear sky kosh-agach 50 88.6667
# 288.71 100 93 2.95 light rain la ciotat 43.1748 5.6045
#  City Not Found
# 286.1 70 47 4.73 broken clouds solnechnyy 50.7214 136.6319
# 291.24 2 84 4.25 clear sky hualmay -11.0964 -77.6139
# 275.15 75 69 2.06 broken clouds qasigiannguit 68.8193 -51.1922
# 298.71 10 73 6.78 clear sky weston 26.1004 -80.3998
# 301.15 0 54 1.37 clear sky chapada dos guimaraes -15.4606 -55.7497
# 298.15 40 100 0.42 scattered clouds benjamin constant -4.3831 -70.0311
# 288.2 100 47 3.76 overcast clouds weihe 32.9952 105.3247
# 276.29 98 63 7.41 overcast clouds hofn 64.2539 -15.2082
# 297.15 75 83 4.63 heavy intensity rain sakaiminato 35.55 133.2333
# 287.94 100 95 2.54 overcast clouds cherdyn 60.403 56.4787
# 296.61 100 96 1.3 overcast clouds coari -4.085 -63.1414
# 287.04 68 91 2.24 broken clouds morro bay 35.3658 -120.8499
# 302.87 93 71 5.52 overcast clouds manggar -2.8833 108.2667
#  City Not Found
#  City Not Found
# 286.46 100 61 5.8 overcast clouds svetlaya 46.5389 138.3297
# 285.15 0 100 1.54 clear sky santa maria -29.6842 -53.8069
# 289.36 87 53 5.95 overcast clouds pervomayskoye 43.919 46.7102
# 291.73 4 74 6.1 clear sky benghazi 32.1167 20.0667
# 296.84 100 80 4.89 overcast clouds harihar 14.5167 75.8
# 284.74 100 19 1.39 overcast clouds shitanjing 39.2342 106.3439
# 297.15 40 100 1.03 scattered clouds wattegama 6.7989 81.4808
# 295.32 95 96 0.72 overcast clouds fuente de oro 3.4594 -73.6128
# 300.15 40 78 8.75 scattered clouds saint-georges 12.0564 -61.7485
#  City Not Found
# 275.15 90 64 4.63 overcast clouds dalvik 65.9702 -18.5286
# 288.15 0 58 2.57 clear sky tagab 34.855 69.6492
# 290.15 75 88 2.57 broken clouds kamaishi 39.2667 141.8833
#  City Not Found
# 302.15 0 51 7.2 clear sky nicoya 10.1483 -85.452
# 296.64 100 50 1.41 overcast clouds jardim -21.4803 -56.1381
# 295.5 97 52 1.3 overcast clouds quirinopolis -18.4483 -50.4517
# 301.87 29 81 4.86 scattered clouds san policarpo 12.1791 125.5072
# 295.56 100 98 1.15 overcast clouds maracacume -2.0428 -45.9592
# 301.72 100 67 1.19 overcast clouds shaowu 27.3409 117.4831
# 279.74 10 57 0.62 clear sky kyzyl-suu 42.3414 78.0056
# 286.15 72 44 1 broken clouds selenginsk 52.0064 106.8647
# 294.76 100 96 0.68 overcast clouds bongandanga 1.5 21.05
# 288.94 0 33 5.36 clear sky tsabong -26.0217 22.401
# 287.46 16 40 1.33 few clouds khandyga 62.6667 135.6
# 304.02 82 65 2.2 broken clouds dong hoi 17.4833 106.6
# 286.64 2 62 1.31 clear sky kaoma -14.7833 24.8
# 290.29 44 96 0.85 scattered clouds nampula -15.1165 39.2666
# 283.06 12 33 3.46 few clouds batagay 67.6333 134.6333
# 292.15 0 77 1.54 clear sky esmeraldas -19.7625 -44.3139
# 301.15 20 47 5.14 few clouds nanakuli 21.3906 -158.1547
# 301.48 100 83 9.83 overcast clouds portobelo 9.55 -79.65
# 283.15 75 93 5 broken clouds uglezavodsk 47.3167 142.6167
# 286.84 28 98 3.08 scattered clouds kologriv 58.8275 44.3178
# 291.18 23 61 3.57 few clouds kupino 54.3663 77.2981
#  City Not Found
#  City Not Found
# 282.59 83 84 0.89 broken clouds margate 51.3813 1.3862
# 282.15 20 53 3.6 few clouds halifax 44.6453 -63.5724
# 287.88 0 30 7.03 clear sky hailar 49.2 119.7
# 274.48 100 84 8.66 overcast clouds mehamn 71.0357 27.8492
# 299.86 100 87 3.47 overcast clouds matara 5.9485 80.5353
# 300.19 6 77 9.96 clear sky hobyo 5.3505 48.5268
# 292.32 0 53 0.54 clear sky ampanihy -24.7 44.75
# 283.15 0 100 2 clear sky ivankiv 50.9386 29.8943
# 294.15 90 94 3.6 light rain seoul 37.5683 126.9778
# 280.37 100 89 1.47 overcast clouds kilcormac 53.1742 -7.7256
# 303.51 26 71 6.5 scattered clouds gaozhou 21.9392 110.8461
# 290.15 66 51 5.66 broken clouds byron bay -28.65 153.6167
# 290.42 18 73 5.58 few clouds marsabit 2.3284 37.9899
# 297.58 100 96 1.24 overcast clouds murindo 6.9848 -76.7544
# 290.93 100 74 1.69 overcast clouds tongzi 28.7829 105.0877
# 277.59 100 86 5.03 overcast clouds saint-augustin 51.226 -58.6502
# 287.15 100 58 2.57 overcast clouds burns lake 54.2331 -125.7533
# 288.97 0 64 1.8 clear sky xudat 41.631 48.681
# 291.15 1 59 4.12 clear sky westport 41.1415 -73.3579
# 298.09 100 83 2.01 overcast clouds yaan 7.3833 8.5667
#  City Not Found
# 293.25 0 72 1.79 clear sky pozo colorado -23.4923 -58.7972
# 288.15 0 77 4 clear sky aksay 47.26 39.87
# ...
# 303.53 100 72 1.89 overcast clouds shirgaon 19.7 72.7
# 292.04 99 36 5.14 overcast clouds weymouth 42.2209 -70.9398
# 289.14 10 83 1.33 clear sky tsiroanomandidy -18.7667 46.0333
# 298.91 73 85 0.54 broken clouds payo -3.7508 103.6372
# 295.09 10 81 0.48 clear sky bulungu -4.55 18.6
# 282.15 40 93 1.54 scattered clouds achim 53.0112 9.033
# 300.93 100 77 4.24 overcast clouds port-gentil -0.7193 8.7815
# 302.98 0 38 7.65 clear sky ubauro 28.1652 69.7289
#  City Not Found
# 287.59 75 88 1.54 broken clouds san giuliano terme 43.7616 10.4404
# 296.15 75 88 6.17 light rain kadoma 34.7333 135.5833
# 285.18 100 97 0.39 overcast clouds lodeynoye pole 60.726 33.5531
# 300.54 98 63 2.57 overcast clouds banikoara 11.2985 2.4386
# 298.99 69 40 1.93 broken clouds nalagarh 31.05 76.7167
# 274.15 90 93 6.69 light snow hammerfest 70.6634 23.6821
# 292.35 82 60 2.46 broken clouds yarkovo 57.4028 67.0786
# 304.82 7 46 2.36 clear sky madhupur 24.25 86.65
# 294.73 100 17 4.67 overcast clouds tongliao 43.6125 122.2653
# 290.29 2 66 1.16 clear sky rasht 37.2808 49.5832
# 278.15 90 100 2.06 mist timra 62.487 17.3257
# 280.15 90 93 2.57 overcast clouds lulea 65.5842 22.1547
# 281.15 0 66 1 clear sky baiyin 36.5583 104.2081
# 292.06 3 94 1.36 clear sky ruangwa -10.0667 38.9333
# 287.83 44 71 0.82 scattered clouds hudson bay 52.85 -102.3842
# 271.06 68 95 2.68 broken clouds dukat 62.55 155.55
# 285.37 33 99 1.17 scattered clouds pontal do parana -25.6533 -48.5128
# 284.15 0 100 1.03 clear sky senaki 42.2704 42.0675
# 299.42 99 89 0.99 light rain hongjiang 27.11 109.9956
# 278.98 100 91 5.27 light rain okha 53.5739 142.9478
#  City Not Found
# 283.15 18 71 4.12 few clouds lunenburg 44.3835 -64.3155
# 290.15 1 39 2.06 clear sky pascoag 41.9557 -71.7023
# 297.15 75 94 4.12 mist kaseda 31.4167 130.3167
# 287.15 90 77 2.06 overcast clouds wisconsin rapids 44.3836 -89.8174
# 277.92 100 70 1.99 overcast clouds pirovskoye 57.6267 92.2658
# 301.15 40 78 4.63 scattered clouds neiafu -18.65 -173.9833
# 290.29 33 41 6.77 scattered clouds vanino 49.0869 140.2543
# 299.89 32 62 3.96 scattered clouds goundi 9.3627 17.366
# 291.15 1 55 3.09 clear sky garni 40.1221 44.7312
#  City Not Found
# 281.15 90 100 2.57 overcast clouds ventspils 57.3894 21.5606
# 283.71 20 62 3.6 few clouds soldotna 60.4878 -151.0583
# 287.59 100 67 1.79 overcast clouds wyoming 43.0002 -107.5009
#  City Not Found
# 285.1 60 54 6.82 broken clouds sangar 63.9242 127.4739
# 282.15 75 93 3.6 broken clouds nexo 55.0607 15.1306
# 285.15 0 87 4 clear sky gomel 52.4345 30.9754
# 285.37 74 89 0.94 broken clouds ripoll 42.2006 2.1903
# 294.74 100 89 0.6 moderate rain nova esperanca 4.438 -61.1151
# 299.15 40 83 8.23 scattered clouds barahona 18.2085 -71.1008
# 290.45 100 97 0.69 overcast clouds caranavi -15.8167 -67.55
# 290.67 4 59 0.79 clear sky kariba -16.5167 28.8
# 285.8 100 79 2.1 overcast clouds koslan 63.4564 48.8989
# 301.45 73 75 5.8 broken clouds pundaguitan 6.3711 126.1689
# 300.75 100 52 1.15 overcast clouds mubi 10.2676 13.2644
# 293.61 67 59 0.74 broken clouds xichang 27.8964 102.2634
# 289.26 99 96 1.85 overcast clouds lyskovo 56.0328 45.0422
# 297.44 6 78 6.62 clear sky garissa -0.4536 39.6401
# 286.15 0 71 2.06 clear sky rivadavia -33.1905 -68.4608
# 284.22 100 87 0.81 overcast clouds kastamonu 41.5 33.6667
# 283.15 100 82 0.45 overcast clouds sangerhausen 51.4667 11.3
#  City Not Found
# 288.28 0 46 6.58 clear sky shirokiy 49.758 129.523
# 286.84 100 56 2.91 overcast clouds beidao 34.5686 105.8933
# 283.15 0 93 2.57 clear sky stargard szczecinski 53.3367 15.0499
#  City Not Found
# 300.65 34 64 3.13 scattered clouds poya -21.35 165.15
#  City Not Found
# 299.82 6 84 0.45 clear sky cabo rojo 18.0866 -67.1457
# 293.15 40 94 3.09 scattered clouds porto belo -27.1578 -48.5531
# 287.3 8 50 1.64 clear sky sesheke -17.4759 24.2968
# 296.11 100 69 1.72 overcast clouds pontes e lacerda -15.2261 -59.3353
# 298.15 75 100 0.36 broken clouds puerto narino -3.7703 -70.3831
# 283.34 100 98 3.92 light rain lipin bor 60.2622 37.9763
# 303.74 100 47 5.57 overcast clouds sabla 12.7525 4.7077
# 299.19 0 12 5.44 clear sky balkanabat 39.5108 54.3671
# 301.15 30 51 2.06 haze bozdar 27.1828 68.636
# 303.26 59 62 1.94 broken clouds sur 22.5667 59.5289
# 295.28 97 92 0.67 overcast clouds uchiza -8.4592 -76.4633
# 287.21 89 93 0.81 moderate rain boditi 6.9667 37.8667
# 292.68 41 58 0.95 scattered clouds buritizeiro -17.3511 -44.9622
# 292.27 100 69 0.5 overcast clouds boyuibe -20.4167 -63.2833
# 287.2 0 34 3.67 clear sky amazar 53.858 120.875
# 285.15 90 94 3.09 light rain knysna -34.0363 23.0471
# 281.47 90 49 5.09 overcast clouds suntar 62.1444 117.6319
# 290.15 100 45 1.54 overcast clouds la tuque 47.4334 -72.7824
# 289.19 100 46 2.83 overcast clouds bolshaya glushitsa 50.2406 43.5908
# 297.15 90 64 5.14 overcast clouds quesada 10.3238 -84.4271
# 290.93 1 39 1.54 clear sky point pleasant 40.0832 -74.0682
# 276.48 100 93 1.58 overcast clouds jedburgh 55.48 -2.552
# 290.37 75 77 7.2 mist portales 34.1862 -103.3344
# 301.15 75 28 7.2 broken clouds guadalajara 20.6667 -103.3333
# 299.2 99 88 1.24 overcast clouds kendari -3.945 122.4989
# 286.09 52 65 0.27 broken clouds catabola -12.15 17.2833
# 290.49 72 91 0.88 broken clouds belo oriente -19.22 -42.4836
# 307.15 1 7 4.63 clear sky north las vegas 36.1989 -115.1175
# 289.05 100 74 2.28 overcast clouds atig 56.6931 59.4227
# 290.41 100 60 0.79 overcast clouds hanzhong 33.0728 107.0303
# 294.59 90 41 1.15 overcast clouds betioky -23.7167 44.3833
# 304.7 44 33 2.25 scattered clouds madaoua 14.073 5.96
# 293.93 94 72 0.36 overcast clouds kaliua -5.0606 31.7936
# 284.26 0 87 1.54 clear sky tutova 46.1167 27.55
# 284.15 75 93 3.09 broken clouds paris 48.8534 2.3488
# 289.82 100 82 1.34 overcast clouds villa carlos paz -31.4241 -64.4978
# 287.15 40 51 3.09 scattered clouds hermon 44.8101 -68.9134
# 292.79 100 98 0.71 overcast clouds nkoteng 4.5167 12.0333
# 302.15 20 84 1.03 few clouds labuan 5.2767 115.2417
#  City Not Found
# 302.68 100 74 11.04 overcast clouds dhidhdhoo 6.8833 73.1
# 290.37 3 94 0.73 clear sky rabat 33.9911 -6.8401
# 288.78 6 64 1.77 clear sky lumeje -11.55 20.7833
# 295.15 4 26 1.54 clear sky rockhampton -23.3833 150.5
# 288.15 90 51 1.72 light rain ingham 42.6 -84.3833
# 289.32 100 83 2.21 overcast clouds gornozavodsk 58.3758 58.3211
# 286.48 90 82 2.06 mist arcata 40.8665 -124.0828
#  City Not Found
# 282.59 0 100 1.54 clear sky hlinsko 49.7621 15.9076
# 291.57 0 36 3.62 clear sky aleksandrov gay 50.147 48.5704
# 299.15 40 83 2.06 scattered clouds santo domingo 18.5001 -69.9886
# 298.71 100 52 3.41 light rain tokamachi 37.1333 138.7667
# 289.82 100 83 1.39 overcast clouds alta gracia -31.6529 -64.4283
# 302.33 100 72 3.95 overcast clouds bhadrachalam 17.6667 80.8833
# 303.15 20 74 0.51 few clouds da nang 16.0678 108.2208
# 300.62 1 30 5.38 clear sky santa rosalia 27.3167 -112.2833
# 298.99 100 55 2.49 overcast clouds itaueira -7.6033 -43.0256
# 303.15 19 58 3.09 few clouds sedhiou 12.7081 -15.5569
#  City Not Found
# 299.15 40 94 1.03 mist savannakhet 16.566 104.751
# 291.69 100 98 0.6 light rain palora -1.7 -77.9333
# 291.38 0 26 6.25 clear sky taybad 34.74 60.7756
# 282.15 90 81 2.57 overcast clouds riviere-au-renard 48.9957 -64.3971
# 282.59 100 87 2.58 overcast clouds drawsko pomorskie 53.5306 15.8097
# 294.82 9 38 0.45 clear sky villena 38.6373 -0.8657
# 289.43 48 72 2.69 scattered clouds glazov 58.1394 52.6584
# 301.75 82 82 4.2 broken clouds anito 12.4497 125.2886
#  City Not Found
# 300.16 0 23 6.85 clear sky port keats -14.25 129.55
# 296.36 100 97 0.42 overcast clouds santo antonio do ica -3.1022 -67.9397
# 291.15 1 45 1.54 clear sky bristol 41.8334 -71.1662
# 288.96 98 53 1.22 overcast clouds rudnaya pristan 44.3614 135.8116
# 279.86 100 90 3.53 overcast clouds huayang 34.4155 109.9939
# 291.17 83 43 1.76 broken clouds chuguyevka 44.1653 133.8633
# 300.37 40 57 9.26 scattered clouds cairns -16.9167 145.7667
# 299.15 75 94 2.06 broken clouds pontianak -0.0333 109.3333
# 296.48 1 68 3.09 clear sky lamar 33.6668 -95.5836
# 290.15 1 42 2.06 clear sky old saybrook 41.2918 -72.3762
# 286.87 6 41 0.36 clear sky teeli 51.0333 90.2333
# 280.15 40 93 2.06 scattered clouds skibbereen 51.55 -9.2667
# 282.77 100 96 2.12 moderate rain koshurnikovo 54.1667 93.3
# 279.19 91 84 3.23 overcast clouds harbour breton 47.4833 -55.7983
# 275.59 100 67 2.97 overcast clouds myaundzha 63.0494 147.1858
# 293.15 0 52 4.63 clear sky perth -31.9333 115.8333
# 286.21 5 73 1.02 clear sky luena -11.7833 19.9167
# 294.18 100 96 4.48 overcast clouds rongcheng 30.634 117.8517
# 284.26 100 90 0.45 overcast clouds forst 51.7333 14.6333
# 283.67 0 52 4.16 clear sky forbes -33.3833 148.0167
# 287.15 40 94 1.34 scattered clouds gornoye loo 43.7129 39.6049
# 303.15 0 70 3 clear sky zhenhai 24.2582 118.0905
# 282.59 96 96 4.48 overcast clouds northeim 51.7 10
# 289.38 100 94 5.74 overcast clouds hede 33.7681 120.2517
# 289.84 100 42 4.85 light rain dongying 37.4564 118.4856
#  City Not Found
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /usr/lib64/python3.6/http/client.py in getresponse(self)
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#
# /usr/lib64/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib64/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# /usr/lib64/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# /usr/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# /usr/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /usr/lib64/python3.6/http/client.py in getresponse(self)
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#
# /usr/lib64/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib64/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# /usr/lib64/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-e771f88bb033> in <module>
#      14     # get method of requests module
#      15     # return response object
# ---> 16     response = requests.get(complete_url)
#      17
#      18     # json method of response object
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# the info() method is really very useful, in particular because it will tell us the data TYPE of each
# column in the dataframe.

# Notice, for example, that Cloudiness and Humidity are actually string objects, whereas we expected them
# to be numerical percentages.  So, we are going to have to deal with that!
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         2017 non-null   object
#  1   Latitude     2017 non-null   float64
#  2   Longitude    2017 non-null   float64
#  3   Max Temp     2017 non-null   float64
#  4   Wind Speed   2017 non-null   float64
#  5   Cloudiness   2017 non-null   float64
#  6   Description  2017 non-null   object
#  7   Humidity     2017 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 126.2+ KB

# %%
# convert the Cloudiness and Humidity colums from strings into numerical values (floating point numbers).
raw_data['Cloudiness'] = raw_data['Cloudiness'].astype(float)
raw_data['Humidity'] = raw_data['Humidity'].astype(float)

# print the dataframe, just to check that everything looks good!
raw_data
# Out:
#              City  Latitude  Longitude  Max Temp  Wind Speed  Cloudiness  \
# 0         rikitea  -23.1203  -134.9692    296.67        8.08       100.0
# 1           pevek   69.7008   170.3133    271.90        0.67        74.0
# 2     new norfolk  -42.7826   147.0587    285.37        2.24       100.0
# 3       stromness   58.9650    -3.2960    281.15        2.06        90.0
# 4          albany   42.6001   -73.9662    291.15        2.06         1.0
# ...           ...       ...        ...       ...         ...         ...
# 2012  gornoye loo   43.7129    39.6049    287.15        1.34        40.0
# 2013      zhenhai   24.2582   118.0905    303.15        3.00         0.0
# 2014     northeim   51.7000    10.0000    282.59        4.48        96.0
# 2015         hede   33.7681   120.2517    289.38        5.74       100.0
# 2016     dongying   37.4564   118.4856    289.84        4.85       100.0
#
#            Description  Humidity
# 0      overcast clouds      67.0
# 1        broken clouds      91.0
# 2           light rain      83.0
# 3      overcast clouds      87.0
# 4            clear sky      32.0
# ...                ...       ...
# 2012  scattered clouds      94.0
# 2013         clear sky      70.0
# 2014   overcast clouds      96.0
# 2015   overcast clouds      94.0
# 2016        light rain      42.0
#
# [2017 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# create a new sub-dataframe that contains only the rows where Humidity>100%
clean_city_high_humidity = raw_data[raw_data['Humidity'] > 100.0]

# check how many rows there are with this condition.
len(clean_city_high_humidity)
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.
# 
#  This step seems unnecessary, even if there is high humidity data, as we can remove those
#  entries in a much simpler way

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#
# The above comments in this cell were the professor's comments.  It is way easier to just parse the dataframe
# in the following way, rather than complicating matters by worrying about specific indices.
clean_city_data = raw_data[raw_data['Humidity'] <= 100.0]

# %%
# Export the clean city data here:
clean_city_data.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# import that data library, and then get today's date: the format will be 'Month XX, YYYY' 
from datetime import date
today = date.today().strftime("%B %d, %Y")

# Make a plot of Max Temp vs. Latitude
#
# <rant>
# Please note:  the accepted way of specifying any x-y plot is to day "y vs. x" (and not x vs. y as your
# professor has done above).  This is a huge pet peeve of mine!!!!!!!!!!!!!  We are trying to see if the temperature
# (i.e the dependent variable) depends on the latitude (i.e. the independent variable).  That is, we are trying
# to answer the question: 'Does Temperature depend on Latitude?'  Thus, we clearly want temperature on the y-axis
# and latitude on the x-axis.
#
# For the plot() method in matplotlib.pyplot, the x-data goes FIRST in the call, and then the y-data goes
# SECOND.  I think that this is probably where this new WRONG way of calling this 'X vs. Y' comes from, and it
# bothers me to no end, and it is just wrong.
# </rant>
#
plt.plot(clean_city_data['Latitude'],clean_city_data['Max Temp'],'b.')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temperature (Kelvin)')
plt.title('World Temperature Data - %s' % today)
plt.savefig('World_Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.plot(clean_city_data['Latitude'],clean_city_data['Humidity'],'b.')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Humidity (percent)')
plt.title('World Humidity Data - %s' % today)
plt.savefig('World_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.plot(clean_city_data['Latitude'],clean_city_data['Cloudiness'],'b.')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Cloudiness (percent)')
plt.title('World Cloudiness Data - %s' % today)
plt.savefig('World_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.plot(clean_city_data['Latitude'],clean_city_data['Wind Speed'],'b.')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Wind Speed (mph)')
plt.title('World Wind Speed Data - %s' % today)
plt.savefig('World_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# The first thing that we want to do here is to create a function which will handle the linear regression 
# and plotting for us.  This will reduce a lot of duplicate coding!
# 
# When we call this function, we are going to pass to it:
#
# 1. the x-data
# 2. the y-data
# 3. the label for the x-axis
# 4. the label for the y-axis
# 5. the title of the plot
#

def linear_plot(x,y,xstring,ystring,thistitle):
    
    # do the linear regression ... all we need to do is to call the lingress() method that we imported above
    res = linregress(x, y)
    slope = res.slope
    intercept = res.intercept
    
    # get today's date
    from datetime import date
    today = date.today().strftime("%B %d, %Y")

    # create the plot
    #
    # first, plot the actual data
    plt.plot(x,y,'b.',label='Data')    
    # next, plot the linear regression fit.
    plt.plot(x, intercept + slope*x, 'r-', label='Linear Fit')
    # finally, add the axis labels, title, and legend
    plt.xlabel(xstring)
    plt.ylabel(ystring)
    plt.title(thistitle % today)
    plt.legend()
    plt.show()
    
    
    # With any linear regression plot, there are typically two things that we can use to decide
    # whether or not the y-variable actually does depend on the x-variable:
    # 
    # 1. The slope of the linear regression, WITH AN ASSOCIATED UNCERTAINTY.
    # 2. The R^2 value (i.e. the correlation coefficient)
    # 
    # The following is some pretty standard code that uses the Student's t-distribution
    # together with summary statistics from the linear regression in order to extract these two quantities.
    #
    from scipy.stats import t
    tinv = lambda p, dof: abs(t.ppf(p/2, dof))
    ts = tinv(0.05, len(x)-2)
    print(f"R-squared: {res.rvalue**2:.6f}")
    print(f"slope (95%): {res.slope:.6f} +/- {ts*res.stderr:.6f}")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
clean_city_north = clean_city_data[clean_city_data['Latitude']>0.0]
clean_city_north.info()

linear_plot(clean_city_north['Latitude'],clean_city_north['Max Temp'],'Latitude (degrees)','Max Temperature (Kelvin)','Northern Hemisphere Temperature Data - %s')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1467 entries, 844 to 22
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         1467 non-null   object
#  1   Latitude     1467 non-null   float64
#  2   Longitude    1467 non-null   float64
#  3   Max Temp     1467 non-null   float64
#  4   Wind Speed   1467 non-null   float64
#  5   Cloudiness   1467 non-null   float64
#  6   Description  1467 non-null   object
#  7   Humidity     1467 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 103.1+ KB
# R-squared: 0.652295
# slope (95%): -0.372092 +/- 0.013923

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
clean_city_south = clean_city_data[clean_city_data['Latitude']<0.0]

linear_plot(clean_city_south['Latitude'],clean_city_south['Max Temp'],'Latitude (degrees)','Max Temperature (Kelvin)','Southern Hemisphere Temperature Data - %s')
# Out:
# R-squared: 0.440197
# slope (95%): 0.339814 +/- 0.032155

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_north['Latitude'],clean_city_north['Humidity'],'Latitude (degrees)','Humidity (percent)','Northern Hemisphere Humidity Data - %s')
# Out:
# R-squared: 0.000026
# slope (95%): 0.006373 +/- 0.064332

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_south['Latitude'],clean_city_south['Humidity'],'Latitude (degrees)','Humidity (percent)','Southern Hemisphere Humidity Data - %s')
# Out:
# R-squared: 0.065296
# slope (95%): 0.371843 +/- 0.118051

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_north['Latitude'],clean_city_north['Cloudiness'],'Latitude (degrees)','Cloudiness (percent)','Northern Hemisphere Cloudiness Data - %s')
# Out:
# R-squared: 0.003166
# slope (95%): 0.120499 +/- 0.109578

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_south['Latitude'],clean_city_south['Cloudiness'],'Latitude (degrees)','Cloudiness (percent)','Southern Hemisphere Cloudiness Data - %s')
# Out:
# R-squared: 0.028383
# slope (95%): 0.581392 +/- 0.285435

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_north['Latitude'],clean_city_north['Wind Speed'],'Latitude (degrees)','WindSpeed(percent)','Northern Hemisphere Wind Speed Data - %s')
# Out:
# R-squared: 0.000090
# slope (95%): 0.001136 +/- 0.006154

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_plot(clean_city_south['Latitude'],clean_city_south['Wind Speed'],'Latitude (degrees)','WindSpeed(percent)','Southern Hemisphere Wind Speed Data - %s')
# Out:
# R-squared: 0.021608
# slope (95%): -0.025767 +/- 0.014549

# %% [markdown]
# ### A Proper Analysis of the Temperature vs. Latitude Data

# %% [markdown]
# #### Now, let's do the fit of temperature vs. latitude correctly!!! ####

# %%
plt.plot(clean_city_data['Latitude'],clean_city_data['Max Temp'],'b.')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temperature (Kelvin)')
plt.title('World Temperature Data - %s' % today)
plt.savefig('World_Temperature.png')
plt.show()

# %%
from scipy.optimize import curve_fit

def fitfunction(x,*paramlist):
    #return paramlist[2]-paramlist[0]*(np.sin(np.pi/180.0*(x-paramlist[1])))**2
    return paramlist[0]+paramlist[1]*x+paramlist[2]*x**2+ \
        paramlist[3]*x**3+paramlist[4]*x**4+paramlist[5]*x**5+paramlist[6]*x**6

#init_vals = [35.0,3.0,300.0]
init_vals = [300,3.0,.3,.03,0.003,0.0003,.00003]

clean_city_data = clean_city_data.sort_values(by=['Latitude'])

xi = clean_city_data['Latitude']
yi = clean_city_data['Max Temp']

popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
#print ("Final Result: y = (%0.2f +/- %0.2f)  - (%0.2f +/- %0.2f)*sin^2(Pi/180(x - (%0.2f +/- %0.2f)) " 
#       % (popt[2],perr[2],popt[0],perr[0],popt[1],perr[1]))

residuals = yi - fitfunction(xi, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((yi-np.mean(yi))**2)
r_squared = 1 - (ss_res / ss_tot)

print(f"R-squared: {r_squared:.6f}")

plt.plot(xi,yi,'.')

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temperature (Kelvin)')
plt.title('World Temperature Data - %s' % today)
plt.show()
# Out:
# Coefficients (from curve_fit)
# [ 2.98881918e+02  2.61381155e-01 -9.53393293e-03 -2.05777837e-04
#   3.14489455e-06  4.93526860e-08 -7.14017162e-10]
# Covariance Matrix (from curve_fit)
# [[ 4.34008524e-02 -1.34612869e-04 -8.06705268e-05  5.83725040e-07
#    3.04475235e-08 -2.72155684e-10 -1.00561883e-12]
#  [-1.34612869e-04  2.61118695e-04 -1.42419306e-06 -3.45760871e-07
#    3.27123117e-09  9.85985299e-11 -1.16292521e-12]
#  [-8.06705268e-05 -1.42419306e-06  2.95761258e-07 -1.58849301e-10
#   -1.52171208e-10  6.71413608e-13  1.15263731e-14]
#  [ 5.83725040e-07 -3.45760871e-07 -1.58849301e-10  5.74104846e-10
#   -4.50615150e-12 -1.86202116e-13  2.11504103e-15]
#  [ 3.04475235e-08  3.27123117e-09 -1.52171208e-10 -4.50615150e-12
#    1.25381087e-13  1.09557235e-15 -2.43578344e-17]
#  [-2.72155684e-10  9.85985299e-11  6.71413608e-13 -1.86202116e-13
#    1.09557235e-15  6.77383332e-17 -7.33738885e-19]
#  [-1.00561883e-12 -1.16292521e-12  1.15263731e-14  2.11504103e-15
#   -2.43578344e-17 -7.33738885e-19  9.60028324e-21]]
#
# R-squared: 0.682851

# %%
# What might we expect?
#
# The earth's rotational axis is perpendicular to the earth-sun axis on the spring and fall equinoxes 
# (March 21 and September 21).  On these dates the sun is directly over the equator.  
# The rotational axis is parallel to the earth-sun axes on the summer and winter solstaces 
# (June 21 and December 21).  On these dates, the sun is directly over the Tropics of Cancer 
# and Capricorn, respectively.  The tilt of the earth's axis is 23.5 degrees.  Today is May 6th.  
# It has been 46 days since the spring equinox.  Therefore, the sun is directly over the latitude 
# corresponding to:  (46/(0.25*365))*23.5 = 11.8 degrees.

flag = True
for i in range(1000):
    theta = -10.0+i/999.0*30.0
    fprime = popt[1]+2.0*popt[2]*theta+3.0*popt[3]*theta**2+ \
        4.0*popt[4]*theta**3+5.0*popt[5]*theta**4+6.0*popt[6]*theta**5
    if (fprime<0.0 and flag):
        print ("Maximum at theta = %0.2f degrees" % theta)
        flag = False
# Out:
# Maximum at theta = 10.90 degrees
