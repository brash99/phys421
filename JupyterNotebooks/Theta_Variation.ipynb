# %%
import numpy as np
import matplotlib.pyplot as plt

from P201_Functions import *

set_dark_mode(True)


theta  = np.array([(1+i)/100.0 for i in range(210)])
thetar = theta*np.pi/180.0
sintheta = np.sin(thetar)

diff = (thetar-sintheta)/sintheta

plt.plot(theta,diff)
plt.xlabel('Theta (degrees)')
plt.ylabel('d(sin(theta))/sin(theta)')
# Out:
# Text(0, 0.5, 'd(sin(theta))/sin(theta)')
