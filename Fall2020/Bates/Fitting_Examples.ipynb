# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# create some fake data

npts = 10
xlow = 0.5
xhigh = 100.0

xl = xlow + 0.01
xmid = (xhigh+xlow)/2.0+0.01

xi = np.linspace(xlow,xhigh,npts)
yrandom = stats.norm.rvs(size=npts,loc=0,scale=.2)
yi = xi + yrandom

# %%
plt.plot(xi,yi,'o')

# %%
from scipy.optimize import curve_fit

def fitfunction(x,*paramlist):
    return paramlist[0]+paramlist[1]*x

init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.plot(xi,yi,'o')

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope = []
dslope = []
yint = []
dyint = []
type = []

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('None')
# Out:
# Coefficients (from curve_fit)
# [0.11331281 0.99938443]
# Covariance Matrix (from curve_fit)
# [[ 6.68427106e-03 -9.50592635e-05]
#  [-9.50592635e-05  1.89172607e-06]]
#
# Final Result: y = (1.00 +/- 0.00) x + (0.11 +/- 0.08)

# %%
sigmai = np.array([0.5 for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Uniform')
# Out:
# Coefficients (from curve_fit)
# [0.11331284 0.99938443]
# Covariance Matrix (from curve_fit)
# [[ 6.68425637e-03 -9.50590416e-05]
#  [-9.50590416e-05  1.89172272e-06]]
#
# Final Result: y = (1.00 +/- 0.00) x + (0.11 +/- 0.08)

# %%
sigmai = np.array([0.1 + 0.25*(xi[i]-xl) for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Increasing')
# Out:
# Coefficients (from curve_fit)
# [0.27579249 0.99394578]
# Covariance Matrix (from curve_fit)
# [[ 5.65036306e-06 -1.86939611e-06]
#  [-1.86939611e-06  3.47848489e-06]]
#
# Final Result: y = (0.99 +/- 0.00) x + (0.28 +/- 0.00)

# %%
sigmai = np.array([0.1+ 0.25*(xi[i]-xmid) for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Endpoints')
# Out:
# Coefficients (from curve_fit)
# [-0.20837545  1.00641443]
# Covariance Matrix (from curve_fit)
# [[ 4.91289527e-02 -9.43959357e-04]
#  [-9.43959357e-04  1.90801695e-05]]
#
# Final Result: y = (1.01 +/- 0.00) x + (-0.21 +/- 0.22)

# %%
df = pd.DataFrame({'Fit Type':type, 'Slope':slope, 'Error in Slope':dslope, 'Y Intercept':yint, 'Error in Y Intercept':dyint})
df.head()
# Out:
#      Fit Type     Slope  Error in Slope  Y Intercept  Error in Y Intercept
# 0        None  0.999384        0.001375     0.113313              0.081757
# 1     Uniform  0.999384        0.001375     0.113313              0.081757
# 2  Increasing  0.993946        0.001865     0.275792              0.002377
# 3   Endpoints  1.006414        0.004368    -0.208375              0.221651

# %%
sigmai = np.array([0.1+ 1.5/np.abs(xi[i]) for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Increasing at Small X')
# Out:
# Coefficients (from curve_fit)
# [0.02755307 1.00060191]
# Covariance Matrix (from curve_fit)
# [[ 1.20346289e-02 -1.60890141e-04]
#  [-1.60890141e-04  2.50038786e-06]]
#
# Final Result: y = (1.00 +/- 0.00) x + (0.03 +/- 0.11)

# %%
df = pd.DataFrame({'Fit Type':type, 'Slope':slope, 'Error in Slope':dslope, 'Y Intercept':yint, 'Error in Y Intercept':dyint})
df.head()
# Out:
#                 Fit Type     Slope  Error in Slope  Y Intercept  \
# 0                   None  0.999384        0.001375     0.113313
# 1                Uniform  0.999384        0.001375     0.113313
# 2             Increasing  0.993946        0.001865     0.275792
# 3              Endpoints  1.006414        0.004368    -0.208375
# 4  Increasing at Small X  1.000602        0.001581     0.027553
#
#    Error in Y Intercept
# 0              0.081757
# 1              0.081757
# 2              0.002377
# 3              0.221651
# 4              0.109702

# %%
# create some fake data

npts = 10
xlow = 0.5
xhigh = 100.0

xl = xlow + 0.01
xmid = (xhigh+xlow)/2.0+0.01

xi = np.linspace(xlow,xhigh,npts)
yi = xi + yrandom

sigmai = np.array([0.1+ 1.5/np.abs(xi[i]) for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Small X Range')
# Out:
# Coefficients (from curve_fit)
# [0.02755307 1.00060191]
# Covariance Matrix (from curve_fit)
# [[ 1.20346289e-02 -1.60890141e-04]
#  [-1.60890141e-04  2.50038786e-06]]
#
# Final Result: y = (1.00 +/- 0.00) x + (0.03 +/- 0.11)

# %%
df = pd.DataFrame({'Fit Type':type, 'Slope':slope, 'Error in Slope':dslope, 'Y Intercept':yint, 'Error in Y Intercept':dyint})
df.head(10)
# Out:
#                 Fit Type     Slope  Error in Slope  Y Intercept  \
# 0                   None  0.999384        0.001375     0.113313
# 1                Uniform  0.999384        0.001375     0.113313
# 2             Increasing  0.993946        0.001865     0.275792
# 3              Endpoints  1.006414        0.004368    -0.208375
# 4  Increasing at Small X  1.000602        0.001581     0.027553
# 5          Small X Range  1.000602        0.001581     0.027553
#
#    Error in Y Intercept
# 0              0.081757
# 1              0.081757
# 2              0.002377
# 3              0.221651
# 4              0.109702
# 5              0.109702

# %%
# create some fake data

npts = 10
xlow = 0.5
xhigh = 100.0

xl = xlow + 0.01
xmid = (xhigh+xlow)/2.0+0.01

xi = np.linspace(xlow,xhigh,npts)
yi = xi + yrandom

sigmai = np.array([0.1+ 1.5/np.abs(xi[i]) for i in range(npts)])
plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
init_vals = [0.0 for x in range(2)]
popt, pcov = curve_fit(fitfunction,xi,yi,p0=init_vals,sigma=sigmai)
perr = np.sqrt(np.diag(pcov))

ps = np.random.multivariate_normal(popt,pcov,10000)
ysample=np.asarray([fitfunction(xi,*pi) for pi in ps])

lower = np.percentile(ysample,2.5,axis=0)
upper = np.percentile(ysample,97.5,axis=0)
middle = (lower+upper)/2.0

print("Coefficients (from curve_fit)")
print (popt)
print("Covariance Matrix (from curve_fit)")
print (pcov)

print()
print ("Final Result: y = (%0.2f +/- %0.2f) x + (%0.2f +/- %0.2f)" % (popt[1],perr[1],popt[0],perr[0]))

plt.errorbar(xi, yi, yerr=sigmai, fmt='o', capsize=5, capthick=2)

plt.plot(xi,middle)
plt.plot(xi,lower)
plt.plot(xi,upper)
plt.show()

slope.append(popt[1])
dslope.append(perr[1])
yint.append(popt[0])
dyint.append(perr[0])
type.append('Large X Range')
# Out:
# Coefficients (from curve_fit)
# [0.02755307 1.00060191]
# Covariance Matrix (from curve_fit)
# [[ 1.20346289e-02 -1.60890141e-04]
#  [-1.60890141e-04  2.50038786e-06]]
#
# Final Result: y = (1.00 +/- 0.00) x + (0.03 +/- 0.11)

# %%
df = pd.DataFrame({'Fit Type':type, 'Slope':slope, 'Error in Slope':dslope, 'Y Intercept':yint, 'Error in Y Intercept':dyint})
df.head(10)
# Out:
#                 Fit Type     Slope  Error in Slope  Y Intercept  \
# 0                   None  0.999384        0.001375     0.113313
# 1                Uniform  0.999384        0.001375     0.113313
# 2             Increasing  0.993946        0.001865     0.275792
# 3              Endpoints  1.006414        0.004368    -0.208375
# 4  Increasing at Small X  1.000602        0.001581     0.027553
# 5          Small X Range  1.000602        0.001581     0.027553
# 6          Large X Range  1.000602        0.001581     0.027553
#
#    Error in Y Intercept
# 0              0.081757
# 1              0.081757
# 2              0.002377
# 3              0.221651
# 4              0.109702
# 5              0.109702
# 6              0.109702
